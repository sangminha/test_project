# %%
import folium
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_rows", None)
pd.set_option('display.max_columns', None)

# %%
seoul_db = pd.read_csv("../Downloads/항공사 (2).csv", encoding="utf-8")
df = seoul_db
df
# Out:
#     조회기간 : 2021.10 ~ 2022.09, 여객 : 전체, 화물 : 전체, 항공사 : 전체, 운항 : 전체, 노선 : 전체, 여객화물 : 전체  \
# 0                                                 항공사명
# 1                                                전체 합계
# 2                                                국적사 계
# 3                                            대한항공(KAL)
# 4                                          아시아나항공(AAR)
# 5                                           에어로케이(EOK)
# 6                                            에어부산(ABL)
# 7                                            에어서울(ASV)
# 8                                            에어인천(AIH)
# 9                                          에어프레미아(APZ)
# 10                                           제주항공(JJA)
# 11                                            진에어(JNA)
# 12                                          티웨이항공(TWB)
# 13                                          플라이강원(FGW)
# 14                                               외항사 계
# ...

# %%
year_2221=df[:123]

# %%
year_2120=df[123:214]

# %%
year_2019=df[214:359]

# %%
year_1918=df[359:457]

# %%
len(year_2221)
# Out:
# 123

# %%
len(year_2120)
# Out:
# 91

# %%
len(year_2019)
# Out:
# 145

# %%
len(year_1918)
# Out:
# 98

# %%
year_2221
# Out:
#     조회기간 : 2021.10 ~ 2022.09, 여객 : 전체, 화물 : 전체, 항공사 : 전체, 운항 : 전체, 노선 : 전체, 여객화물 : 전체  \
# 0                                                 항공사명
# 1                                                전체 합계
# 2                                                국적사 계
# 3                                            대한항공(KAL)
# 4                                          아시아나항공(AAR)
# 5                                           에어로케이(EOK)
# 6                                            에어부산(ABL)
# 7                                            에어서울(ASV)
# 8                                            에어인천(AIH)
# 9                                          에어프레미아(APZ)
# 10                                           제주항공(JJA)
# 11                                            진에어(JNA)
# 12                                          티웨이항공(TWB)
# 13                                          플라이강원(FGW)
# 14                                               외항사 계
# ...

# %%
x=['1918','2019','2120','2221']
y=[123,91,145,98]


plt.bar(x, y)
plt.xticks(x,)
# Out:
# ([<matplotlib.axis.XTick at 0x7f8c878dfbb0>,
# ...
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %%
y_2221=[year_2221["Unnamed: 1"][1],year_2221["Unnamed: 2"][1],year_2221["Unnamed: 3"][1],year_2221["Unnamed: 4"][1]]
y_2221
# Out:
# ['60,526,526', '377,549', '48,387,770', '3,575,877']

# %%
y_2120=[year_2120["Unnamed: 1"][123],year_2120["Unnamed: 2"][123],year_2120["Unnamed: 3"][123],year_2120["Unnamed: 4"][123]]
y_2120
# Out:
# ['5,980,594', '33,138', '4,762,919', '283,989']

# %%
y_2019=[year_2019["Unnamed: 1"][214],year_2019["Unnamed: 2"][214],year_2019["Unnamed: 3"][214],year_2019["Unnamed: 4"][214]]
y_2019
# Out:
# ['81,815,751', '437,565', '62,384,451', '3,511,447']

# %%
y_1918=[year_1918["Unnamed: 1"][359],year_1918["Unnamed: 2"][359],year_1918["Unnamed: 3"][359],year_1918["Unnamed: 4"][359]]
y_1918
# Out:
# ['147,841,992', '722,040', '123,246,556', '4,303,814']

# %%
y_sum[0]=[60526526,5980594,81815751,147841992]
y_sum[0]
# Out:
# [60526526, 5980594, 81815751, 147841992]

# %%
y_sum[2]
# Out:
# [123246556, 62384451, 4762919, 48387770]

# %%
plt.plot(x,y_sum[0])
plt.show()

# %%
y_sum[1]=[722040,437565,33138,377549]
y_sum[1]
# Out:
# [722040, 437565, 33138, 377549]

# %%
y_sum[2]=[123246556,62384451,4762919,48387770]

# %%
y_sum[3]=[4303814,3511447,283989,3575877]

# %%
plt.plot(x,y_sum[1])
plt.show()

# %%
plt.plot(x,y_sum[2])
plt.show()

# %%
plt.plot(x,y_sum[3])
plt.show()

# %%
plt.plot(x, y_sum[0],'r', label = "Supply")

plt.plot(x, y_sum[1],'b',label = "navigation")


plt.plot(x, y_sum[2],'g',label = "passenger")
plt.plot(x, y_sum[3],'k',label = "Cargo")
plt.legend()

plt.show()
