# %%
import folium
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option("display.max_rows", None)
pd.set_option('display.max_columns', None)

# %%
pd.set_option("display.max_rows", None)
pd.set_option('display.max_columns', None)

# %%
lol_db = pd.read_csv("../Documents//페이커 롤 솔랭_1.csv", encoding="utf-8")
df = lol_db
df
# Out:
#             챔피언    게임수      승률   KDA     킬   데쓰    어시     CS   평균 골드   트리플  \
# 0            베인  105.0  74.28%  3.25  10.1  5.0   6.1  181.6  11,860  30.0
# 1        블리츠크랭크   68.0  51.47%  3.27   2.7  4.4  11.7   27.7   7,993   0.0
# 2           리 신   40.0  52.50%  3.66   7.0  4.2   8.2   55.4   9,698   2.0
# 3          그라가스   35.0     60%  4.23   9.0  3.5   5.9  220.6  12,365   2.0
# 4            피즈   29.0  72.41%  3.08  10.7  5.1   5.2  160.5  12,420   3.0
# 5     트위스티드 페이트   20.0     80%  3.36   6.8  3.9   6.1  185.4  10,975   0.0
# 6            케넨   20.0     70%  2.27   5.8  5.2   6.2  202.0  10,979   4.0
# 7           이블린   19.0  31.57%  2.28   6.3  5.9   7.1   79.2   9,857   0.0
# 8           니달리   18.0  72.22%  3.46   6.9  4.0   6.9  156.9  10,485   2.0
# 9           쓰레쉬   18.0  61.11%  3.16   2.9  5.1  13.3   32.9   7,793   0.0
# 10        마스터 이   18.0  55.55%  2.68   9.8  5.3   4.4  105.9  11,940   6.0
# ...

# %%
z=df['챔피언'].dropna()
a=df['승률'].dropna()
b=df['KDA'].dropna()
c=df['킬'].dropna()
d=df['데쓰'].dropna()
e=df['어시'].dropna()
z[37]='레넥톤'     
a_drop=a.str.replace('%','').astype(float)

# %%
plt.plot(z, a_drop,
         color='skyblue',
         marker='o', markerfacecolor='blue',
         markersize=6)
# Out:
# /Users/hansangmin/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48288 (\N{HANGUL SYLLABLE BE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hansangmin/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hansangmin/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48660 (\N{HANGUL SYLLABLE BEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hansangmin/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
plt.plot(z, a_drop/10,marker='o',markersize=6)
plt.plot(z, b,marker='o',markersize=6)
plt.plot(z, c,marker='o',markersize=6)
plt.plot(z, d,marker='o',markersize=6)
plt.plot(z, e,marker='o',markersize=6)
# Out:
# /Users/hansangmin/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48288 (\N{HANGUL SYLLABLE BE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hansangmin/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hansangmin/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48660 (\N{HANGUL SYLLABLE BEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hansangmin/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
z_1=df['챔피언.1'].dropna()
a_1=df['승률.1'].dropna()
b_1=df['KDA.1'].dropna()
c_1=df['킬.1'].dropna()
d_1=df['데쓰.1'].dropna()
e_1=df['어시.1'].dropna()

# %%
plt.plot(z, a_1,marker='o',markersize=6)
plt.plot(z, b_1,marker='o',markersize=6)
plt.plot(z, c_1,marker='o',markersize=6)
plt.plot(z, d_1,marker='o',markersize=6)
plt.plot(z, e_1,marker='o',markersize=6)
plt.show()
# Out:
# /Users/hansangmin/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48288 (\N{HANGUL SYLLABLE BE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hansangmin/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hansangmin/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 48660 (\N{HANGUL SYLLABLE BEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/hansangmin/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
lol_1 = pd.read_excel("../Documents/롤 페이커 공식.xlsx")
lol_1
# Out:
#                               all                          Unnamed: 1  \
# 0                         Record:                         655W - 314L
# 1                       Win Rate:                                 NaN
# 2                             NaN                               0.676
# 3                            KDA:                                 4.3
# 4                  CS per Minute:                                 8.9
# 5                Gold Per Minute:                                 413
# 6                          Gold%:                               0.221
# 7             Kill Participation:                                0.65
# 8                             NaN                                 NaN
# 9                   PERSONAL BEST                                 NaN
# 10                           KDA:   11/0/8 - Afreeca Freecs vs SKT T1
# 11                           DPM:       1158 DPM - CJ Entus vs SKT T1
# ...

# %%
lol = pd.read_csv("../Documents/페이커 and 정글.csv", encoding="utf-8")
lol
# Out:
#                      Unnamed: 0   Unnamed: 1    Unnamed: 2 Unnamed: 3  \
# 0                      T1 Faker          NaN           NaN        NaN
# 1                이상혁 1996-05-07          NaN           NaN        NaN
# 2                      T1 | Mid          NaN           NaN        NaN
# 3                         정규 시즌          NaN           NaN        NaN
# 4                       최근 10경기          NaN           NaN        NaN
# 5                            6승          NaN           NaN        NaN
# 6                            4패          NaN           NaN        NaN
# 7                        승률 60%          NaN           NaN        NaN
# 8                   2022 LCK 서머          NaN           NaN        NaN
# 9                     정규 시즌 KDA          NaN           NaN        NaN
# 10                          4.3          NaN           NaN        NaN
# 11              2.5 / 2.2 / 6.9          NaN           NaN        NaN
# ...

# %%
faker_2013=lol[148:155]
faker_2013
# Out:
#          Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 148     2013 LCK 윈터         15         15          0       100%         86
# 149  2013 WCG 국대선발전          4          2          2        50%         17
# 150        2013 롤드컵         18         15          3     83.30%         80
# 151  2013 롤드컵 국대선발전          4          3          1        75%         28
# 152     2013 LCK 서머         18         15          3     83.30%        110
# 153   2013 AMD 챔피언십          4          2          2        50%         22
# 154    2013 LCK 스프링         20         14          6        70%        133
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 148         26         97        5.7        1.7         6.5           7
# 149         12         13        4.3          3         3.3         2.5
# 150         39        108        4.4        2.2           6         4.8
# 151         10         32          7        2.5           8           6
# ...

# %%
faker_2014=lol[141:148]

# %%
faker_2015=lol[134:141]

# %%
faker_2016=lol[125:134]

# %%
faker_2017=lol[116:125]

# %%
faker_2018=lol[109:116]

# %%
faker_2019=lol[101:109]

# %%
faker_2020=lol[94:101]

# %%
faker_2021=lol[88:94]

# %%
faker_2022=lol[82:88]

# %%
Bengi=lol[186:215]
Bengi
# Out:
#            Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 186         2016 올스타전          3          3          0       100%         14
# 187       2016 KeSPA컵          3          2          1     66.70%         11
# 188          2016 롤드컵         10          8          2        80%         26
# 189       2016 LCK 서머         14          8          6     57.10%         27
# 190      2016 LCK 스프링         17         11          6     64.70%         22
# 191       2015 KeSPA컵          5          2          3        40%         11
# 192          2015 롤드컵         16         15          1     93.80%         36
# 193    2015 LCK 서머 PS          3          3          0       100%         13
# 194       2015 LCK 서머         35         29          6     82.90%         86
# 195   2015 LCK 스프링 PS          3          3          0       100%          6
# 196          2015 MSI         15         10          5     66.70%         34
# ...

# %%
blank=lol[217:236]
blank
# Out:
#            Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 217     018 롤드컵 국대선발전          5          2          3        40%          6
# 218     2018 리프트 라이벌즈          4          2          2        50%         12
# 219       2018 LCK 서머         39         19         20     48.70%         47
# 220   2018 LCK 스프링 PS          7          3          4     42.90%          8
# 221      2018 LCK 스프링         24         10         14     41.70%         24
# 222       2017 KeSPA컵          5          2          3        40%         10
# 223          2017 롤드컵          9          5          4     55.60%         13
# 224    2017 LCK 서머 PS          6          4          2     66.70%         12
# 225     2017 리프트 라이벌즈          1          1          0       100%          1
# 226       2017 LCK 서머         17         14          3     82.40%         45
# 227      2017 LCK 스프링          6          6          0       100%         26
# ...

# %%
peaneat=lol[238:246]

# %%
clid=lol[248:256]

# %%
cuzz=lol[258:264]

# %%
oner=lol[266:277]
oner
# Out:
#           Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 266         2022 롤드컵         13         11          2     84.60%         38
# 267   2021 LCK 서머 PS          8          3          5     37.50%         16
# 268      2022 LCK 서머         44         31         13     70.50%        127
# 269         2022 MSI         24         18          6        75%         76
# 270  2022 LCK 스프링 PS          7          6          1     85.70%         32
# 271     2022 LCK 스프링         43         36          7     83.70%        154
# 272         2021 롤드컵         14         10          4     71.40%         44
# 273   2021 롤드컵 국대선발전          5          3          2        60%         19
# 274   2021 LCK 서머 PS         11          7          4     63.60%         40
# 275      2021 LCK 서머         21         13          8     61.90%         54
# 276     2021 LCK 스프링          9          5          4     55.60%         30
#
# ...

# %%
win_2013=faker_2013['Unnamed: 2'].astype(float)
win_2014=faker_2014['Unnamed: 2'].astype(float)
win_2015=faker_2015['Unnamed: 2'].astype(float)
win_2016=faker_2016['Unnamed: 2'].astype(float)
win_2017=faker_2017['Unnamed: 2'].astype(float)
win_2018=faker_2018['Unnamed: 2'].astype(float)
win_2019=faker_2019['Unnamed: 2'].astype(float)
win_2020=faker_2020['Unnamed: 2'].astype(float)
win_2021=faker_2021['Unnamed: 2'].astype(float)
win_2022=faker_2022['Unnamed: 2'].astype(float)

# %%
Loss_2013=faker_2013['Unnamed: 3'].astype(float)
Loss_2014=faker_2014['Unnamed: 3'].astype(float)
Loss_2015=faker_2015['Unnamed: 3'].astype(float)
Loss_2016=faker_2016['Unnamed: 3'].astype(float)
Loss_2017=faker_2017['Unnamed: 3'].astype(float)
Loss_2018=faker_2018['Unnamed: 3'].astype(float)
Loss_2019=faker_2019['Unnamed: 3'].astype(float)
Loss_2020=faker_2020['Unnamed: 3'].astype(float)
Loss_2021=faker_2021['Unnamed: 3'].astype(float)
Loss_2022=faker_2022['Unnamed: 3'].astype(float)

# %%
sum_0_4=sum(grade_sum_kill1)/len(grade_sum_kill1)
sum_1_4=sum(grade_sum_death1)/len(grade_sum_death1)
sum_2_4=sum(grade_sum_help1)/len(grade_sum_help1)
sum_3_4=sum(grade_sum_K_M1)/len(grade_sum_K_M1)
sum_4_4=sum(grade_sum_D_M1)/len(grade_sum_D_M1)
sum_5_4=sum(grade_sum_A_M1)/len(grade_sum_A_M1)
sum_6_4=sum(grade_sum_KDA1)/len(grade_sum_KDA1)
sum_7_4=sum(grade_sum_kill_help1)/len(grade_sum_kill_help1)


oner_0=sum(grade15.iloc[0])/len(grade15.iloc[0])
oner_1=sum(grade15.iloc[1])/len(grade15.iloc[1])
oner_2=sum(grade15.iloc[2])/len(grade15.iloc[2])
oner_3=sum(grade15.iloc[3])/len(grade15.iloc[3])
oner_4=sum(grade15.iloc[4])/len(grade15.iloc[4])
oner_5=sum(grade15.iloc[5])/len(grade15.iloc[5])
oner_6=sum(grade15.iloc[6])/len(grade15.iloc[6])
oner_7=sum(grade15.iloc[7])/len(grade15.iloc[7])


faker_oner_0=sum_0_3-oner_0
faker_oner_1=sum_1_3-oner_1
faker_oner_2=sum_2_3-oner_2
faker_oner_3=sum_3_3-oner_3
faker_oner_4=sum_4_3-oner_4
faker_oner_5=sum_5_3-oner_5
faker_oner_6=sum_6_3-oner_6
faker_oner_7=sum_7_3-oner_7

oner_faker=pd.DataFrame([faker_oner_0,faker_oner_1,faker_oner_2,faker_oner_3,faker_oner_4,faker_oner_5,faker_oner_6,faker_oner_7],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"])
oner_faker
# Out:
#               0
# kill  -0.939394
# death  3.166667
# help  -7.143939
# k/m   -0.519697
# d/m   -0.084091
# A/M   -0.884848
# KDA   -0.389394
# K/H   -6.565152

# %%
faker_kill_2013=faker_2013['Unnamed: 5'].astype(float)

# %%
faker_death_2013=faker_2013['Unnamed: 6'].astype(float)

# %%
faker_help_2013=faker_2013['Unnamed: 7'].astype(float)

# %%
faker_K_M_2013=faker_2013['Unnamed: 8'].astype(float)

# %%
faker_D_M_2013=faker_2013['Unnamed: 9'].astype(float)

# %%
faker_AM_2013=faker_2013['Unnamed: 10'].astype(float)

# %%
faker_K_D_A_2013=faker_2013['Unnamed: 11'].astype(float)

# %%
faker_Kill_help_2013=faker_2013['Unnamed: 12'].str.replace('%','').astype(float)

# %%
faker_kill_2014=faker_2014['Unnamed: 5'].astype(float)
faker_death_2014=faker_2014['Unnamed: 6'].astype(float)
faker_help_2014=faker_2014['Unnamed: 7'].astype(float)
faker_K_M_2014=faker_2014['Unnamed: 8'].astype(float)
faker_D_M_2014=faker_2014['Unnamed: 9'].astype(float)
faker_AM_2014=faker_2014['Unnamed: 10'].astype(float)
faker_K_D_A_2014=faker_2014['Unnamed: 11'].astype(float)
faker_Kill_help_2014=faker_2014['Unnamed: 12'].str.replace('%','').astype(float)

# %%
faker_kill_2015=faker_2015['Unnamed: 5'].astype(float)
faker_death_2015=faker_2015['Unnamed: 6'].astype(float)
faker_help_2015=faker_2015['Unnamed: 7'].astype(float)
faker_K_M_2015=faker_2015['Unnamed: 8'].astype(float)
faker_D_M_2015=faker_2015['Unnamed: 9'].astype(float)
faker_AM_2015=faker_2015['Unnamed: 10'].astype(float)
faker_K_D_A_2015=faker_2015['Unnamed: 11'].astype(float)
faker_Kill_help_2015=faker_2015['Unnamed: 12'].str.replace('%','').astype(float)

# %%
faker_kill_2016=faker_2016['Unnamed: 5'].astype(float)
faker_death_2016=faker_2016['Unnamed: 6'].astype(float)
faker_help_2016=faker_2016['Unnamed: 7'].astype(float)
faker_K_M_2016=faker_2016['Unnamed: 8'].astype(float)
faker_D_M_2016=faker_2016['Unnamed: 9'].astype(float)
faker_AM_2016=faker_2016['Unnamed: 10'].astype(float)
faker_K_D_A_2016=faker_2016['Unnamed: 11'].astype(float)
faker_Kill_help_2016=faker_2016['Unnamed: 12'].str.replace('%','').astype(float)

# %%
faker_kill_2017=faker_2017['Unnamed: 5'].astype(float)
faker_death_2017=faker_2017['Unnamed: 6'].astype(float)
faker_help_2017=faker_2017['Unnamed: 7'].astype(float)
faker_K_M_2017=faker_2017['Unnamed: 8'].astype(float)
faker_D_M_2017=faker_2017['Unnamed: 9'].astype(float)
faker_AM_2017=faker_2017['Unnamed: 10'].astype(float)
faker_K_D_A_2017=faker_2017['Unnamed: 11'].astype(float)
faker_Kill_help_2017=faker_2017['Unnamed: 12'].str.replace('%','').astype(float)

# %%
faker_kill_2018=faker_2018['Unnamed: 5'].astype(float)
faker_death_2018=faker_2018['Unnamed: 6'].astype(float)
faker_help_2018=faker_2018['Unnamed: 7'].astype(float)
faker_K_M_2018=faker_2018['Unnamed: 8'].astype(float)
faker_D_M_2018=faker_2018['Unnamed: 9'].astype(float)
faker_AM_2018=faker_2018['Unnamed: 10'].astype(float)
faker_K_D_A_2018=faker_2018['Unnamed: 11'].astype(float)
faker_Kill_help_2018=faker_2018['Unnamed: 12'].str.replace('%','').astype(float)

# %%
faker_kill_2019=faker_2019['Unnamed: 5'].astype(float)
faker_death_2019=faker_2019['Unnamed: 6'].astype(float)
faker_help_2019=faker_2019['Unnamed: 7'].astype(float)
faker_K_M_2019=faker_2019['Unnamed: 8'].astype(float)
faker_D_M_2019=faker_2019['Unnamed: 9'].astype(float)
faker_AM_2019=faker_2019['Unnamed: 10'].astype(float)
faker_K_D_A_2019=faker_2019['Unnamed: 11'].astype(float)
faker_Kill_help_2019=faker_2019['Unnamed: 12'].str.replace('%','').astype(float)

# %%
faker_kill_2020=faker_2020['Unnamed: 5'].astype(float)
faker_death_2020=faker_2020['Unnamed: 6'].astype(float)
faker_help_2020=faker_2020['Unnamed: 7'].astype(float)
faker_K_M_2020=faker_2020['Unnamed: 8'].astype(float)
faker_D_M_2020=faker_2020['Unnamed: 9'].astype(float)
faker_AM_2020=faker_2020['Unnamed: 10'].astype(float)
faker_K_D_A_2020=faker_2020['Unnamed: 11'].astype(float)
faker_Kill_help_2020=faker_2020['Unnamed: 12'].str.replace('%','').astype(float)

# %%
faker_kill_2021=faker_2021['Unnamed: 5'].astype(float)
faker_death_2021=faker_2021['Unnamed: 6'].astype(float)
faker_help_2021=faker_2021['Unnamed: 7'].astype(float)
faker_K_M_2021=faker_2021['Unnamed: 8'].astype(float)
faker_D_M_2021=faker_2021['Unnamed: 9'].astype(float)
faker_AM_2021=faker_2021['Unnamed: 10'].astype(float)
faker_K_D_A_2021=faker_2021['Unnamed: 11'].astype(float)
faker_Kill_help_2021=faker_2021['Unnamed: 12'].str.replace('%','').astype(float)

# %%
faker_kill_2022=faker_2022['Unnamed: 5'].astype(float)
faker_death_2022=faker_2022['Unnamed: 6'].astype(float)
faker_help_2022=faker_2022['Unnamed: 7'].astype(float)
faker_K_M_2022=faker_2022['Unnamed: 8'].astype(float)
faker_D_M_2022=faker_2022['Unnamed: 9'].astype(float)
faker_AM_2022=faker_2022['Unnamed: 10'].astype(float)
faker_K_D_A_2022=faker_2022['Unnamed: 11'].astype(float)
faker_Kill_help_2022=faker_2022['Unnamed: 12'].str.replace('%','').astype(float)

# %%
grade_0=pd.DataFrame([faker_kill_2013,faker_death_2013,faker_help_2013,faker_K_M_2013,faker_D_M_2013,faker_AM_2013,faker_K_D_A_2013,faker_Kill_help_2013],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"])

# %%
grade_0
# Out:
#         148   149    150   151    152   153    154
# kill   86.0  17.0   80.0  28.0  110.0  22.0  133.0
# death  26.0  12.0   39.0  10.0   46.0  11.0   63.0
# help   97.0  13.0  108.0  32.0  117.0  29.0  137.0
# k/m     5.7   4.3    4.4   7.0    6.1   5.5    6.7
# d/m     1.7   3.0    2.2   2.5    2.6   2.8    3.2
# A/M     6.5   3.3    6.0   8.0    6.5   7.3    6.9
# KDA     7.0   2.5    4.8   6.0    4.9   4.6    4.3
# K/H    68.3  47.3   62.3  77.3   69.4  76.5   74.3

# %%
grade_1=pd.DataFrame([faker_kill_2014,faker_death_2014,faker_help_2014,faker_K_M_2014,faker_D_M_2014,faker_AM_2014,faker_K_D_A_2014,faker_Kill_help_2014],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"])
grade_1
# Out:
#         141   142   143   144   145   146    147
# kill   31.0  41.0  61.0  63.0  38.0  38.0   66.0
# death  22.0  24.0  22.0  22.0  32.0  27.0   35.0
# help   30.0  50.0  71.0  65.0  80.0  63.0  107.0
# k/m     4.4   4.1   6.1   7.0   3.5   4.2    5.1
# d/m     3.1   2.4   2.2   2.4   2.9   3.0    2.7
# A/M     4.3   5.0   7.1   7.2   7.3   7.0    8.2
# KDA     2.8   3.8   6.0   5.8   3.7   3.7    4.9
# K/H    78.6  66.5  73.4  67.3  68.6  65.0   66.4

# %%
grade_2=pd.DataFrame([faker_kill_2015,faker_death_2015,faker_help_2015,faker_K_M_2015,faker_D_M_2015,faker_AM_2015,faker_K_D_A_2015,faker_Kill_help_2015],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"])
grade_3=pd.DataFrame([faker_kill_2016,faker_death_2016,faker_help_2016,faker_K_M_2016,faker_D_M_2016,faker_AM_2016,faker_K_D_A_2016,faker_Kill_help_2016],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"])
grade_4=pd.DataFrame([faker_kill_2017,faker_death_2017,faker_help_2017,faker_K_M_2017,faker_D_M_2017,faker_AM_2017,faker_K_D_A_2017,faker_Kill_help_2017],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"])
grade_5=pd.DataFrame([faker_kill_2018,faker_death_2018,faker_help_2018,faker_K_M_2018,faker_D_M_2018,faker_AM_2018,faker_K_D_A_2018,faker_Kill_help_2018],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"])
grade_6=pd.DataFrame([faker_kill_2019,faker_death_2019,faker_help_2019,faker_K_M_2019,faker_D_M_2019,faker_AM_2019,faker_K_D_A_2019,faker_Kill_help_2019],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"])
grade_7=pd.DataFrame([faker_kill_2020,faker_death_2020,faker_help_2020,faker_K_M_2020,faker_D_M_2020,faker_AM_2020,faker_K_D_A_2020,faker_Kill_help_2020],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"])
grade_8=pd.DataFrame([faker_kill_2021,faker_death_2021,faker_help_2021,faker_K_M_2021,faker_D_M_2021,faker_AM_2021,faker_K_D_A_2021,faker_Kill_help_2021],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"])
grade_9=pd.DataFrame([faker_kill_2022,faker_death_2022,faker_help_2022,faker_K_M_2022,faker_D_M_2022,faker_AM_2022,faker_K_D_A_2022,faker_Kill_help_2022],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"])

# %%
cate=['kill','death','help','K/M','D/M','A/M','KDA','killhelp']

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade_0)

plt.show()

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade_1)

plt.show()

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade_2)

plt.show()

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade_3)

plt.show()

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade_4)

plt.show()

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade_5)

plt.show()

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade_6)

plt.show()

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade_7)

plt.show()

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade_8)

plt.show()

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade_9)

plt.show()

# %%
Bengi5=Bengi['Unnamed: 5'].astype(float).fillna(0)
Bengi6=Bengi['Unnamed: 6'].astype(float).fillna(0)
Bengi7=Bengi['Unnamed: 7'].astype(float).fillna(0)
Bengi8=Bengi['Unnamed: 8'].astype(float).fillna(0)
Bengi9=Bengi['Unnamed: 9'].astype(float).fillna(0)
Bengi10=Bengi['Unnamed: 10'].astype(float).fillna(0)
Bengi11=Bengi['Unnamed: 11'].astype(float).fillna(0)
Bengi12=Bengi['Unnamed: 12'].str.replace('%','').astype(float).fillna(0)

# %%
grade10=pd.DataFrame([Bengi5,
         Bengi6,
         Bengi7,
         Bengi8,
         Bengi9,
         Bengi10,
         Bengi11,
         Bengi12],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"])
grade10
# Out:
#         186   187   188   189    190   191    192   193    194   195    196  \
# kill   14.0  11.0  26.0  27.0   22.0  11.0   36.0  13.0   86.0   6.0   34.0
# death   9.0   7.0  17.0  32.0   40.0  11.0   31.0   7.0   69.0   7.0   51.0
# help   22.0  25.0  72.0  81.0  112.0  38.0  144.0  21.0  292.0  53.0  138.0
# k/m     4.7   3.7   2.6   1.9    1.3   2.2    2.3   4.3    2.5   2.0    2.3
# d/m     3.0   2.3   1.7   2.3    2.4   2.2    1.9   2.3    2.0   2.3    3.4
# A/M     7.3   8.3   7.2   5.8    6.6   7.6    9.0   7.0    8.3  17.7    9.2
# KDA     4.0   5.1   5.8   3.4    3.4   4.5    5.8   4.9    5.5   8.4    3.4
# K/H    60.0  90.7  65.0  70.9   63.9  65.8   65.4  58.3   65.8  88.3   71.8
#
#          197    198   199   200   201   202   203   204    205    206   207  \
# kill    46.0   30.0  11.0  14.0  28.0  40.0  21.0  27.0   42.0   37.0   5.0
# death   86.0   22.0  33.0  26.0  26.0  18.0  35.0  27.0   35.0   26.0   8.0
# ...

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade10)

plt.show()

# %%
blank5=blank['Unnamed: 5'].astype(float)
blank6=blank['Unnamed: 6'].astype(float)
blank7=blank['Unnamed: 7'].astype(float)
blank8=blank['Unnamed: 8'].astype(float)
blank9=blank['Unnamed: 9'].astype(float)
blank10=blank['Unnamed: 10'].astype(float)
blank11=blank['Unnamed: 11'].astype(float)
blank12=blank['Unnamed: 12'].str.replace('%','').astype(float)

# %%
grade11=pd.DataFrame([blank5,
         blank6,
         blank7,
         blank8,
         blank9,
         blank10,
         blank11,
         blank12],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"])

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade11)

plt.show()

# %%
peaneat5=peaneat['Unnamed: 5'].astype(float)
peaneat6=peaneat['Unnamed: 6'].astype(float)
peaneat7=peaneat['Unnamed: 7'].astype(float)
peaneat8=peaneat['Unnamed: 8'].astype(float)
peaneat9=peaneat['Unnamed: 9'].astype(float)
peaneat10=peaneat['Unnamed: 10'].astype(float)
peaneat11=peaneat['Unnamed: 11'].astype(float)
peaneat12=peaneat['Unnamed: 12'].str.replace('%','').astype(float)

# %%
grade12=pd.DataFrame([peaneat5,
         peaneat6,
         peaneat7,
         peaneat8,
         peaneat9,
         peaneat10,
         peaneat11,
         peaneat12],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"])

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade12)

plt.show()

# %%
clid5=clid['Unnamed: 5'].astype(float)
clid6=clid['Unnamed: 6'].astype(float)
clid7=clid['Unnamed: 7'].astype(float)
clid8=clid['Unnamed: 8'].astype(float)
clid9=clid['Unnamed: 9'].astype(float)
clid10=clid['Unnamed: 10'].astype(float)
clid11=clid['Unnamed: 11'].astype(float)
clid12=clid['Unnamed: 12'].str.replace('%','').astype(float)

# %%
grade13=pd.DataFrame([clid5,
         clid6,
         clid7,
         clid8,
         clid9,
         clid10,
         clid11,
         clid12],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"])

# %%
cuzz5=cuzz['Unnamed: 5'].astype(float)
cuzz6=cuzz['Unnamed: 6'].astype(float)
cuzz7=cuzz['Unnamed: 7'].astype(float)
cuzz8=cuzz['Unnamed: 8'].astype(float)
cuzz9=cuzz['Unnamed: 9'].astype(float)
cuzz10=cuzz['Unnamed: 10'].astype(float)
cuzz11=cuzz['Unnamed: 11'].astype(float)
cuzz12=cuzz['Unnamed: 12'].str.replace('%','').astype(float)

# %%
grade14=pd.DataFrame([cuzz5,
         cuzz6,
         cuzz7,
         cuzz8,
         cuzz9,
         cuzz10,
         cuzz11,
         cuzz12],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"])

# %%
oner5=oner['Unnamed: 5'].astype(float)
oner6=oner['Unnamed: 6'].astype(float)
oner7=oner['Unnamed: 7'].astype(float)
oner8=oner['Unnamed: 8'].astype(float)
oner9=oner['Unnamed: 9'].astype(float)
oner10=oner['Unnamed: 10'].astype(float)
oner11=oner['Unnamed: 11'].astype(float)
oner12=oner['Unnamed: 12'].str.replace('%','').astype(float)

# %%
grade15=pd.DataFrame([oner5,
         oner6,
         oner7,
         oner8,
         oner9,
         oner10,
         oner11,
         oner12],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"])

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade13)

plt.show()

# %%
plt.figure(figsize=(13,6))
cate=['kill','death','help','K/M','D/M','A/M','KDA','killhelp']
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade14)

plt.show()

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade15)

plt.show()

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade_0)
ax.plot(grade_1)
ax.plot(grade_2)
ax.plot(grade_3)


plt.show()

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(grade10)
ax.plot(grade11)
ax.plot(grade12)
ax.plot(grade13)
ax.plot(grade14)
ax.plot(grade15)


plt.show()

# %%
grade_sum_kill=pd.concat([grade_0.iloc[0],grade_1.iloc[0],grade_2.iloc[0]])
grade_sum_death=pd.concat([grade_0.iloc[1],grade_1.iloc[1],grade_2.iloc[1]])
grade_sum_help=pd.concat([grade_0.iloc[2],grade_1.iloc[2],grade_2.iloc[2]])
grade_sum_K_M=pd.concat([grade_0.iloc[3],grade_1.iloc[3],grade_2.iloc[3]])
grade_sum_D_M=pd.concat([grade_0.iloc[4],grade_1.iloc[4],grade_2.iloc[4]])
grade_sum_A_M=pd.concat([grade_0.iloc[5],grade_1.iloc[5],grade_2.iloc[5]])
grade_sum_KDA=pd.concat([grade_0.iloc[6],grade_1.iloc[6],grade_2.iloc[6]])
grade_sum_kill_help=pd.concat([grade_0.iloc[7],grade_1.iloc[7],grade_2.iloc[7]])

# %%
sum_0=sum(grade_sum_kill)/len(grade_sum_kill)
sum_1=sum(grade_sum_death)/len(grade_sum_death)
sum_2=sum(grade_sum_help)/len(grade_sum_help)
sum_3=sum(grade_sum_K_M)/len(grade_sum_K_M)
sum_4=sum(grade_sum_D_M)/len(grade_sum_D_M)
sum_5=sum(grade_sum_A_M)/len(grade_sum_A_M)
sum_6=sum(grade_sum_KDA)/len(grade_sum_KDA)
sum_7=sum(grade_sum_kill_help)/len(grade_sum_kill_help)


benggi_0=sum(grade10.iloc[0])/len(grade10.iloc[0])
benggi_1=sum(grade10.iloc[1])/len(grade10.iloc[1])
benggi_2=sum(grade10.iloc[2])/len(grade10.iloc[2])
benggi_3=sum(grade10.iloc[3])/len(grade10.iloc[3])
benggi_4=sum(grade10.iloc[4])/len(grade10.iloc[4])
benggi_5=sum(grade10.iloc[5])/len(grade10.iloc[5])
benggi_6=sum(grade10.iloc[6])/len(grade10.iloc[6])
benggi_7=sum(grade10.iloc[7])/len(grade10.iloc[7])


faker_bengi_0=sum_0-benggi_0
faker_bengi_1=sum_1-benggi_1
faker_bengi_2=sum_2-benggi_2
faker_bengi_3=sum_3-benggi_3
faker_bengi_4=sum_4-benggi_4
faker_bengi_5=sum_5-benggi_5
faker_bengi_6=sum_6-benggi_6
faker_bengi_7=sum_7-benggi_7


bengi_faker=pd.DataFrame([faker_bengi_0,faker_bengi_1,faker_bengi_2,faker_bengi_3,faker_bengi_4,faker_bengi_5,faker_bengi_6,faker_bengi_7],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"],columns=['Bengi'])
bengi_faker
# Out:
#            Bengi
# kill   34.880131
# death  -0.975369
# help  -24.361248
# k/m     2.890805
# d/m    -0.168637
# A/M    -2.395731
# KDA     0.375862
# K/H     1.790640

# %%
sum_0_2=sum(grade_4.iloc[0])/len(grade_4.iloc[0])
sum_1_2=sum(grade_4.iloc[0])/len(grade_4.iloc[0])
sum_2_2=sum(grade_4.iloc[0])/len(grade_4.iloc[0])
sum_3_2=sum(grade_4.iloc[0])/len(grade_4.iloc[0])
sum_4_2=sum(grade_4.iloc[0])/len(grade_4.iloc[0])
sum_5_2=sum(grade_4.iloc[0])/len(grade_4.iloc[0])
sum_6_2=sum(grade_4.iloc[0])/len(grade_4.iloc[0])
sum_7_2=sum(grade_4.iloc[0])/len(grade_4.iloc[0])


peaneat_0=sum(grade12.iloc[0])/len(grade12.iloc[0])
peaneat_1=sum(grade12.iloc[1])/len(grade12.iloc[1])
peaneat_2=sum(grade12.iloc[2])/len(grade12.iloc[2])
peaneat_3=sum(grade12.iloc[3])/len(grade12.iloc[3])
peaneat_4=sum(grade12.iloc[4])/len(grade12.iloc[4])
peaneat_5=sum(grade12.iloc[5])/len(grade12.iloc[5])
peaneat_6=sum(grade12.iloc[6])/len(grade12.iloc[6])
peaneat_7=sum(grade12.iloc[7])/len(grade12.iloc[7])


faker_peaneat_0=sum_0_2-peaneat_0
faker_peaneat_1=sum_1_2-peaneat_1
faker_peaneat_2=sum_2_2-peaneat_2
faker_peaneat_3=sum_3_2-peaneat_3
faker_peaneat_4=sum_4_2-peaneat_4
faker_peaneat_5=sum_5_2-peaneat_5
faker_peaneat_6=sum_6_2-peaneat_6
faker_peaneat_7=sum_7_2-peaneat_7

peaneat_faker=pd.DataFrame([faker_peaneat_0,faker_peaneat_1,faker_peaneat_2,faker_peaneat_3,faker_peaneat_4,faker_peaneat_5,faker_peaneat_6,faker_peaneat_7],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"],columns=['Peaneat'])
peaneat_faker
# Out:
#          Peaneat
# kill   13.888889
# death  34.263889
# help  -15.361111
# k/m    55.463889
# d/m    57.188889
# A/M    52.926389
# KDA    53.151389
# K/H    -9.323611

# %%
sum_0_4=sum(grade_5.iloc[0])/len(grade_5.iloc[0])
sum_1_4=sum(grade_5.iloc[0])/len(grade_5.iloc[0])
sum_2_4=sum(grade_5.iloc[0])/len(grade_5.iloc[0])
sum_3_4=sum(grade_5.iloc[0])/len(grade_5.iloc[0])
sum_4_4=sum(grade_5.iloc[0])/len(grade_5.iloc[0])
sum_5_4=sum(grade_5.iloc[0])/len(grade_5.iloc[0])
sum_6_4=sum(grade_5.iloc[0])/len(grade_5.iloc[0])
sum_7_4=sum(grade_5.iloc[0])/len(grade_5.iloc[0])


clid_0=sum(grade13.iloc[0])/len(grade13.iloc[0])
clid_1=sum(grade13.iloc[1])/len(grade13.iloc[1])
clid_2=sum(grade13.iloc[2])/len(grade13.iloc[2])
clid_3=sum(grade13.iloc[3])/len(grade13.iloc[3])
clid_4=sum(grade13.iloc[4])/len(grade13.iloc[4])
clid_5=sum(grade13.iloc[5])/len(grade13.iloc[5])
clid_6=sum(grade13.iloc[6])/len(grade13.iloc[6])
clid_7=sum(grade13.iloc[7])/len(grade13.iloc[7])


faker_clid_0=sum_0_4-clid_0
faker_clid_1=sum_1_4-clid_1
faker_clid_2=sum_2_4-clid_2
faker_clid_3=sum_3_4-clid_3
faker_clid_4=sum_4_4-clid_4
faker_clid_5=sum_5_4-clid_5
faker_clid_6=sum_6_4-clid_6
faker_clid_7=sum_7_4-clid_7


clid_faker=pd.DataFrame([faker_clid_0,faker_clid_1,faker_clid_2,faker_clid_3,faker_clid_4,faker_clid_5,faker_clid_6,faker_clid_7],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"],columns=['Clid'])
clid_faker
# Out:
#             Clid
# kill   -5.607143
# death   8.267857
# help  -76.857143
# k/m    37.267857
# d/m    38.317857
# A/M    33.230357
# KDA    34.730357
# K/H   -29.682143

# %%
sum_0_1=sum(grade_5.iloc[0])/len(grade_5.iloc[0])
sum_1_1=sum(grade_5.iloc[1])/len(grade_5.iloc[1])
sum_2_1=sum(grade_5.iloc[2])/len(grade_5.iloc[2])
sum_3_1=sum(grade_5.iloc[3])/len(grade_5.iloc[3])
sum_4_1=sum(grade_5.iloc[4])/len(grade_5.iloc[4])
sum_5_1=sum(grade_5.iloc[5])/len(grade_5.iloc[5])
sum_6_1=sum(grade_5.iloc[6])/len(grade_5.iloc[6])
sum_7_1=sum(grade_5.iloc[7])/len(grade_5.iloc[7])

blank_0=sum(grade11.iloc[0])/len(grade11.iloc[0])
blank_1=sum(grade11.iloc[1])/len(grade11.iloc[1])
blank_2=sum(grade11.iloc[2])/len(grade11.iloc[2])
blank_3=sum(grade11.iloc[3])/len(grade11.iloc[3])
blank_4=sum(grade11.iloc[4])/len(grade11.iloc[4])
blank_5=sum(grade11.iloc[5])/len(grade11.iloc[5])
blank_6=sum(grade11.iloc[6])/len(grade11.iloc[6])
blank_7=sum(grade11.iloc[7])/len(grade11.iloc[7])


faker_blank_0=sum_0_1-blank_0
faker_blank_1=sum_1_1-blank_1
faker_blank_2=sum_2_1-blank_2
faker_blank_3=sum_3_1-blank_3
faker_blank_4=sum_4_1-blank_4
faker_blank_5=sum_5_1-blank_5
faker_blank_6=sum_6_1-blank_6
faker_blank_7=sum_7_1-blank_7


blank_faker=pd.DataFrame([faker_blank_0,faker_blank_1,faker_blank_2,faker_blank_3,faker_blank_4,faker_blank_5,faker_blank_6,faker_blank_7],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"],columns=['Blank'])
blank_faker
# Out:
#            Blank
# kill   14.142857
# death   4.661654
# help  -16.300752
# k/m     0.562406
# d/m     0.310526
# A/M    -2.818045
# KDA    -2.033835
# K/H    -1.762406

# %%
sum_0_5=sum(grade_7.iloc[0])/len(grade_7.iloc[0])
sum_1_5=sum(grade_7.iloc[0])/len(grade_7.iloc[0])
sum_2_5=sum(grade_7.iloc[0])/len(grade_7.iloc[0])
sum_3_5=sum(grade_7.iloc[0])/len(grade_7.iloc[0])
sum_4_5=sum(grade_7.iloc[0])/len(grade_7.iloc[0])
sum_5_5=sum(grade_7.iloc[0])/len(grade_7.iloc[0])
sum_6_5=sum(grade_7.iloc[0])/len(grade_7.iloc[0])
sum_7_5=sum(grade_7.iloc[0])/len(grade_7.iloc[0])


cuzz_0=sum(grade14.iloc[0])/len(grade14.iloc[0])
cuzz_1=sum(grade14.iloc[1])/len(grade14.iloc[1])
cuzz_2=sum(grade14.iloc[2])/len(grade14.iloc[2])
cuzz_3=sum(grade14.iloc[3])/len(grade14.iloc[3])
cuzz_4=sum(grade14.iloc[4])/len(grade14.iloc[4])
cuzz_5=sum(grade14.iloc[5])/len(grade14.iloc[5])
cuzz_6=sum(grade14.iloc[6])/len(grade14.iloc[6])
cuzz_7=sum(grade14.iloc[7])/len(grade14.iloc[7])


faker_cuzz_0=sum_0_5-cuzz_0
faker_cuzz_1=sum_1_5-cuzz_1
faker_cuzz_2=sum_2_5-cuzz_2
faker_cuzz_3=sum_3_5-cuzz_3
faker_cuzz_4=sum_4_5-cuzz_4
faker_cuzz_5=sum_5_5-cuzz_5
faker_cuzz_6=sum_6_5-cuzz_6
faker_cuzz_7=sum_7_5-cuzz_7


cuzz_faker=pd.DataFrame([faker_cuzz_0,faker_cuzz_1,faker_cuzz_2,faker_cuzz_3,faker_cuzz_4,faker_cuzz_5,faker_cuzz_6,faker_cuzz_7],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"],columns=['Cuzz'])
cuzz_faker
# Out:
#             Cuzz
# kill   11.690476
# death  15.523810
# help  -57.642857
# k/m    37.923810
# d/m    38.073810
# A/M    33.857143
# KDA    33.690476
# K/H   -29.559524

# %%
grade_sum_kill1=pd.concat([grade_8.iloc[0],grade_9.iloc[0]])
grade_sum_death1=pd.concat([grade_8.iloc[1],grade_9.iloc[1]])
grade_sum_help1=pd.concat([grade_8.iloc[2],grade_9.iloc[2]])
grade_sum_K_M1=pd.concat([grade_8.iloc[3],grade_9.iloc[3]])
grade_sum_D_M1=pd.concat([grade_8.iloc[4],grade_9.iloc[4]])
grade_sum_A_M1=pd.concat([grade_8.iloc[5],grade_9.iloc[5]])
grade_sum_KDA1=pd.concat([grade_8.iloc[6],grade_9.iloc[6]])
grade_sum_kill_help1=pd.concat([grade_8.iloc[7],grade_9.iloc[0]])

# %%
sum_0_3=sum(grade_sum_kill1)/len(grade_sum_kill1)
sum_1_3=sum(grade_sum_death1)/len(grade_sum_death1)
sum_2_3=sum(grade_sum_help1)/len(grade_sum_help1)
sum_3_3=sum(grade_sum_K_M1)/len(grade_sum_K_M1)
sum_4_3=sum(grade_sum_D_M1)/len(grade_sum_D_M1)
sum_5_3=sum(grade_sum_A_M1)/len(grade_sum_A_M1)
sum_6_3=sum(grade_sum_KDA1)/len(grade_sum_KDA1)
sum_7_3=sum(grade_sum_kill_help1)/len(grade_sum_kill_help1)


oner_0=sum(grade15.iloc[0])/len(grade15.iloc[0])
oner_1=sum(grade15.iloc[1])/len(grade15.iloc[1])
oner_2=sum(grade15.iloc[2])/len(grade15.iloc[2])
oner_3=sum(grade15.iloc[3])/len(grade15.iloc[3])
oner_4=sum(grade15.iloc[4])/len(grade15.iloc[4])
oner_5=sum(grade15.iloc[5])/len(grade15.iloc[5])
oner_6=sum(grade15.iloc[6])/len(grade15.iloc[6])
oner_7=sum(grade15.iloc[7])/len(grade15.iloc[7])


faker_oner_0=sum_0_3-oner_0
faker_oner_1=sum_1_3-oner_1
faker_oner_2=sum_2_3-oner_2
faker_oner_3=sum_3_3-oner_3
faker_oner_4=sum_4_3-oner_4
faker_oner_5=sum_5_3-oner_5
faker_oner_6=sum_6_3-oner_6
faker_oner_7=sum_7_3-oner_7

oner_faker=pd.DataFrame([faker_oner_0,faker_oner_1,faker_oner_2,faker_oner_3,faker_oner_4,faker_oner_5,faker_oner_6,faker_oner_7],index = ["kill", "death", "help", "k/m","d/m","A/M","KDA","K/H"],columns=['Oner'])
oner_faker
# Out:
#            Oner
# kill  -0.939394
# death  3.166667
# help  -7.143939
# k/m   -0.519697
# d/m   -0.084091
# A/M   -0.884848
# KDA   -0.389394
# K/H   -6.565152

# %%
grade_0.std
grade_1.std
grade_2.std
grade_3.std
faker_std=pd.concat([grade_0.std,grade_1.std,grade_2.std,grade_3.std])
faker_std
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [787], in <cell line: 5>()
#       3 grade_2.std
#       4 grade_3.std
# ----> 5 faker_std=pd.concat([grade_0.std,grade_1.std,grade_2.std,grade_3.std])
#       6 faker_std
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
# ...

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=8)
plt.xticks(labe_1,cate,fontsize=13)
ax.plot(bengi_faker,label='faker-bengi')
ax.plot(blank_faker,label='faker-blank')
ax.plot(clid_faker,label='faker-clid')
ax.plot(cuzz_faker,label='faker-cuzz')
ax.plot(peaneat_faker,label='faker-peaneat')
ax.plot(oner_faker,label='faker-oner')
plt.legend()

plt.show()

# %%
plt.figure(figsize=(13,6))
plt.xticks(labe_1,cate,fontsize=13)
plt.plot(bengi_faker,label='faker-bengi')
plt.plot(blank_faker,label='faker-blank')
plt.plot(clid_faker,label='faker-clid')
plt.plot(cuzz_faker,label='faker-cuzz')
plt.plot(oner_faker,label='faker-oner')
plt.plot(peaneat_faker,label='faker-peaneat')
plt.legend()

plt.show()

# %%
faker_2013_2016=pd.concat([win_2013,win_2014,win_2015,win_2016]).sort_index(ascending=True)
a=sum(faker_2013_2016)/len(faker_2013_2016)

# %%
faker_2017=pd.concat([win_2017]).sort_index(ascending=True)
b=sum(faker_2017)/len(faker_2017)

# %%
faker_2018=pd.concat([win_2018]).sort_index(ascending=True)
c=sum(faker_2018)/len(faker_2018)

# %%
faker_2019=pd.concat([win_2019]).sort_index(ascending=True)
d=sum(faker_2019)/len(faker_2019)

# %%
faker_2020=pd.concat([win_2020]).sort_index(ascending=True)
e=sum(faker_2020)/len(faker_2020)

# %%
faker_2021_2022=pd.concat([win_2021,win_2022]).sort_index(ascending=True)
f=sum(faker_2021_2022)/len(faker_2021_2022)

# %%
faker_2013_2016_loss=pd.concat([Loss_2013,Loss_2014,Loss_2014,Loss_2014]).sort_index(ascending=True)
s=sum(faker_2013_2016_loss)/len(faker_2013_2016_loss)
faker_2017_loss=pd.concat([Loss_2017]).sort_index(ascending=True)
v=sum(faker_2017_loss)/len(faker_2017_loss)
faker_2018_loss=pd.concat([Loss_2018]).sort_index(ascending=True)
w=sum(faker_2018_loss)/len(faker_2018_loss)
faker_2019_loss=pd.concat([Loss_2019]).sort_index(ascending=True)
x=sum(faker_2019_loss)/len(faker_2019_loss)
faker_2020_loss=pd.concat([Loss_2020]).sort_index(ascending=True)
y=sum(faker_2020_loss)/len(faker_2020_loss)
faker_2021_2022_loss=pd.concat([Loss_2021,Loss_2022]).sort_index(ascending=True)
z=sum(faker_2021_2022_loss)/len(faker_2021_2022_loss)

# %%
sum_zero_mean=pd.concat([bengi_faker,blank_faker,peaneat_faker,clid_faker,cuzz_faker,oner_faker],axis=1)

sum_zero_mean
# Out:
#            Bengi      Blank    Peaneat       Clid       Cuzz      Oner
# kill   34.880131  14.142857  13.888889  -5.607143  11.690476 -0.939394
# death  -0.975369   4.661654  34.263889   8.267857  15.523810  3.166667
# help  -24.361248 -16.300752 -15.361111 -76.857143 -57.642857 -7.143939
# k/m     2.890805   0.562406  55.463889  37.267857  37.923810 -0.519697
# d/m    -0.168637   0.310526  57.188889  38.317857  38.073810 -0.084091
# A/M    -2.395731  -2.818045  52.926389  33.230357  33.857143 -0.884848
# KDA     0.375862  -2.033835  53.151389  34.730357  33.690476 -0.389394
# K/H     1.790640  -1.762406  -9.323611 -29.682143 -29.559524 -6.565152

# %%
sun_zero_str=

# %%
for col in range(len(sum_zero["Bengi"])):
    grade_2013_mean = sum_zero["Bengi"][col].mean()
    grade_2013_std = sum_zero["Bengi"][col].std()
    sum_zero["Bengi"][col] = np.var(sum_zero["Bengi"][col])
for col in range(len(sum_zero["Blank"])):
    grade_2014_mean = sum_zero["Blank"][col].mean()
    grade_2014_std = sum_zero["Blank"][col].std()
    sum_zero["Blank"][col] = np.var(sum_zero["Bengi"][col])
for col in range(len(sum_zero["Peaneat"])):
    grade_2015_mean = sum_zero["Peaneat"][col].mean()
    grade_2015_std = sum_zero["Peaneat"][col].std()
    sum_zero["Peaneat"][col] = np.var(sum_zero["Bengi"][col])
for col in range(len(sum_zero["Bengi"])):
    grade_2016_mean = sum_zero["Clid"][col].mean()
    grade_2016_std = sum_zero["Clid"][col].std()
    sum_zero["Clid"][col] = np.var(sum_zero["Clid"][col])

for col in range(len(sum_zero["Cuzz"])):
    grade_2017_mean = sum_zero["Cuzz"][col].mean()
    grade_2017_std = sum_zero["Cuzz"][col].std()
    sum_zero["Cuzz"][col] = np.var(sum_zero["Bengi"][col])
for col in range(len(sum_zero["Bengi"])):
    grade_2018_mean = sum_zero["Oner"][col].mean()
    grade_2018_std = sum_zero["Oner"][col].std()
    sum_zero["Oner"][col] = np.var(sum_zero["Oner"][col])

# %%
sum_zero["Bengi"][0].std()
# Out:
# 34.88013136288998

# %%
sum_zero=pd.concat([bengi_faker,blank_faker,peaneat_faker,clid_faker,cuzz_faker,oner_faker],axis=1)
sum_zero=sum_zero.drop(index=(["help"]))
sum_zero=sum_zero.drop(index=(["K/H"]))
sum_zero

# %%
sum_plus=pd.DataFrame([a,b,c,d,e,f],index=['benggi','balnk','peaneant','clid','cuzz','oner'],columns=['win'])
sum_plus

# %%
sum_minus=pd.DataFrame([s,v,w,x,y,z],index=['benggi','balnk','peaneant','clid','cuzz','oner'],columns=['LOSS'])
sum_minus

# %%
faker_win_LOSS=pd.concat([sum_plus,sum_minus],axis=1)
faker_win_LOSS

# %%
X=sum_zero
print(X)
Y=faker_win_LOSS
print(Y)

# %%
plt.plot(faker_win_LOSS)
plt.show()

# %%
cate_1=['kill', 'death', 'K/M', 'D/M', 'A/M', 'KDA']

# %%
plt.figure(figsize=(13,6))
ax=plt.subplot(polar=True)
labe_1=np.linspace(start=0,stop=2*np.pi-1,num=6)
plt.xticks(labe_1,cate_1,fontsize=13)
ax.plot(X.iloc[0],label='faker-bengi')
ax.plot(X.iloc[1],label='faker-blank')
ax.plot(X.iloc[2],label='faker-clid')
ax.plot(X.iloc[3],label='faker-cuzz')
ax.plot(X.iloc[4],label='faker-peaneat')
ax.plot(X.iloc[5],label='faker-oner')
plt.legend()

plt.show()

# %%
imp

# %%
X=sum_zero.astype(int)
Y=faker_win_LOSS.astype(int)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3)
print(X_train)
print(X_test)
print(Y_train)
print(Y_test)

# %%
from sklearn.metrics import (accuracy_score,precision_score,recall_score,f1_score,roc_auc_score)
def get_clf(Y_test,pred):
    acc=accuracy_score(Y_test,pred)
    pre=precision_score(Y_test,pred)
    re=recall_score(Y_test,pred)
    f1=f1(Y_test,pred)
    auc=roc(Y_test,pred)
    
    return acc,pre,re,f1,auc

# %%
from sklearn.metrics import confusion_matrix

def print_clf(Y_test,pred):
    confusion=confusion_matrix(Y_test,pred)
    acc,pre,re,f1,auc=get_clf(Y_test,pred)
    
    print(confusion)
    print(format(acc,pre))
    print(format(re,f1,auc))

# %%
from sklearn.linear_model import LogisticRegression
lr_clf=LogisticRegression()
lr_clf.fit(X_train,Y_train)
lr_pre=lr_clf.predict(X_test)
print_clf(Y_test,lr_pre)
