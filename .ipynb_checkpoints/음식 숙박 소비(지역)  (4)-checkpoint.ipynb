# %%
import folium
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_rows", None)
pd.set_option('display.max_columns', None)

# %%
 korea1718_db = pd.read_csv("../Downloads/가구당_월평균_가계지출__전국_1인이상_실질__20221022184331.csv", encoding="cp949")
df = korea1718_db
df
# Out:
#              가계지출항목별(1)     2017    2017.1   2017.2     2017.3   2017.4  \
# 0            가계지출항목별(1)     전체가구  전체가구 중위값    근로자가구  근로자가구 중위값   근로자외가구
# 1              가구원수 (명)     2.46         -     2.60          -     2.30
# 2             가구주연령 (세)    51.57         -    46.27          -    57.87
# 3              가구분포 (%)   100.00         -    54.30          -    45.70
# 4              가계지출 (원)  3396121   2831945  3877093    3350386  2824671
# 5              소비지출 (원)  2618489   2193344  2913063    2487285  2268500
# 6    01.식료품 · 비주류음료 (원)   386832    333391   385818     341315   388038
# 7        02.주류 · 담배 (원)    35234     28339    39767      30970    29848
# 8        03.의류 · 신발 (원)   162128    117249   186115     134377   133629
# 9   04.주거 · 수도 · 광열 (원)   289762    212039   303247     221408   273741
# 10  05.가정용품 · 가사서비스 (원)   117049     59087   132449      66084    98751
# 11            06.보건 (원)   185300     84396   181653      86129   189634
# ...

# %%
korea2019_db = pd.read_csv("../Downloads/가구당_월평균_가계수지__전국_1인이상__20221022184358.csv", encoding="cp949")
kf = korea2019_db
kf
# Out:
#             가계수지항목별 2019.1/4 2019.1/4.1 2019.1/4.2 2019.2/4 2019.2/4.1  \
# 0           가계수지항목별     전체가구      근로자가구     근로자외가구     전체가구      근로자가구
# 1          가구원수 (명)     2.42       2.61       2.18     2.41       2.56
# 2         가구주연령 (세)    52.20      46.71      59.57    52.15      47.60
# 3          가구분포 (%)   100.00      57.28      42.72   100.00      59.72
# 4                소득  4271911    5219758    3000893  4168865    4890840
# 5              경상소득  4187631    5142679    2906957  4111302    4845590
# 6              근로소득  2767115    4448305     512720  2715584    4196454
# 7              사업소득   774345     191951    1555308   833315     228785
# 8              재산소득    34095      30432      39008    45210      50009
# 9              이전소득   612075     471991     799921   517194     370343
# 10            비경상소득    84280      77079      93936    57563      45249
# 11             가계지출  3458752    4027578    2695984  3191378    3653718
# ...

# %%
df = df.drop(index=0, axis=0)
df
# Out:
#              가계지출항목별(1)     2017   2017.1   2017.2   2017.3   2017.4   2017.5  \
# 1              가구원수 (명)     2.46        -     2.60        -     2.30        -
# 2             가구주연령 (세)    51.57        -    46.27        -    57.87        -
# 3              가구분포 (%)   100.00        -    54.30        -    45.70        -
# 4              가계지출 (원)  3396121  2831945  3877093  3350386  2824671  2208029
# 5              소비지출 (원)  2618489  2193344  2913063  2487285  2268500  1773219
# 6    01.식료품 · 비주류음료 (원)   386832   333391   385818   341315   388038   322159
# 7        02.주류 · 담배 (원)    35234    28339    39767    30970    29848    24290
# 8        03.의류 · 신발 (원)   162128   117249   186115   134377   133629    92576
# 9   04.주거 · 수도 · 광열 (원)   289762   212039   303247   221408   273741   199097
# 10  05.가정용품 · 가사서비스 (원)   117049    59087   132449    66084    98751    50498
# 11            06.보건 (원)   185300    84396   181653    86129   189634    81950
# ...

# %%
df_2 = df.drop(['가계지출항목별(1)'], axis = 1)

# %%
df_2
# Out:
#        2017   2017.1   2017.2   2017.3   2017.4   2017.5     2018   2018.1  \
# 1      2.46        -     2.60        -     2.30        -     2.43        -
# 2     51.57        -    46.27        -    57.87        -    51.83        -
# 3    100.00        -    54.30        -    45.70        -   100.00        -
# 4   3396121  2831945  3877093  3350386  2824671  2208029  3357451  2822275
# 5   2618489  2193344  2913063  2487285  2268500  1773219  2561049  2168332
# 6    386832   333391   385818   341315   388038   322159   383079   331414
# 7     35234    28339    39767    30970    29848    24290    35359    30082
# 8    162128   117249   186115   134377   133629    92576   153481   112424
# 9    289762   212039   303247   221408   273741   199097   290239   221255
# 10   117049    59087   132449    66084    98751    50498   119658    60621
# 11   185300    84396   181653    86129   189634    81950   194905    90765
# ...

# %%
df = df.drop(index=1,axis=0)
df
# Out:
#              가계지출항목별(1)     2017   2017.1   2017.2   2017.3   2017.4   2017.5  \
# 2             가구주연령 (세)    51.57        -    46.27        -    57.87        -
# 3              가구분포 (%)   100.00        -    54.30        -    45.70        -
# 4              가계지출 (원)  3396121  2831945  3877093  3350386  2824671  2208029
# 5              소비지출 (원)  2618489  2193344  2913063  2487285  2268500  1773219
# 6    01.식료품 · 비주류음료 (원)   386832   333391   385818   341315   388038   322159
# 7        02.주류 · 담배 (원)    35234    28339    39767    30970    29848    24290
# 8        03.의류 · 신발 (원)   162128   117249   186115   134377   133629    92576
# 9   04.주거 · 수도 · 광열 (원)   289762   212039   303247   221408   273741   199097
# 10  05.가정용품 · 가사서비스 (원)   117049    59087   132449    66084    98751    50498
# 11            06.보건 (원)   185300    84396   181653    86129   189634    81950
# 12            07.교통 (원)   364495   169436   430154   202218   286485   126386
# ...

# %%
df = df.drop(index=2,axis=0)
df
# Out:
#              가계지출항목별(1)     2017   2017.1   2017.2   2017.3   2017.4   2017.5  \
# 3              가구분포 (%)   100.00        -    54.30        -    45.70        -
# 4              가계지출 (원)  3396121  2831945  3877093  3350386  2824671  2208029
# 5              소비지출 (원)  2618489  2193344  2913063  2487285  2268500  1773219
# 6    01.식료품 · 비주류음료 (원)   386832   333391   385818   341315   388038   322159
# 7        02.주류 · 담배 (원)    35234    28339    39767    30970    29848    24290
# 8        03.의류 · 신발 (원)   162128   117249   186115   134377   133629    92576
# 9   04.주거 · 수도 · 광열 (원)   289762   212039   303247   221408   273741   199097
# 10  05.가정용품 · 가사서비스 (원)   117049    59087   132449    66084    98751    50498
# 11            06.보건 (원)   185300    84396   181653    86129   189634    81950
# 12            07.교통 (원)   364495   169436   430154   202218   286485   126386
# 13            08.통신 (원)   130763   113416   145554   128833   113190    92373
# ...

# %%
df = df.drop(index=3,axis=0)
df
# Out:
#              가계지출항목별(1)     2017   2017.1   2017.2   2017.3   2017.4   2017.5  \
# 4              가계지출 (원)  3396121  2831945  3877093  3350386  2824671  2208029
# 5              소비지출 (원)  2618489  2193344  2913063  2487285  2268500  1773219
# 6    01.식료품 · 비주류음료 (원)   386832   333391   385818   341315   388038   322159
# 7        02.주류 · 담배 (원)    35234    28339    39767    30970    29848    24290
# 8        03.의류 · 신발 (원)   162128   117249   186115   134377   133629    92576
# 9   04.주거 · 수도 · 광열 (원)   289762   212039   303247   221408   273741   199097
# 10  05.가정용품 · 가사서비스 (원)   117049    59087   132449    66084    98751    50498
# 11            06.보건 (원)   185300    84396   181653    86129   189634    81950
# 12            07.교통 (원)   364495   169436   430154   202218   286485   126386
# 13            08.통신 (원)   130763   113416   145554   128833   113190    92373
# 14       09.오락 · 문화 (원)   173340    88211   198751   112801   143148    60758
# ...

# %%
df_2 = df.drop(['가계지출항목별(1)'], axis = 1)

# %%
df_2
# Out:
#        2017   2017.1   2017.2   2017.3   2017.4   2017.5     2018   2018.1  \
# 4   3396121  2831945  3877093  3350386  2824671  2208029  3357451  2822275
# 5   2618489  2193344  2913063  2487285  2268500  1773219  2561049  2168332
# 6    386832   333391   385818   341315   388038   322159   383079   331414
# 7     35234    28339    39767    30970    29848    24290    35359    30082
# 8    162128   117249   186115   134377   133629    92576   153481   112424
# 9    289762   212039   303247   221408   273741   199097   290239   221255
# 10   117049    59087   132449    66084    98751    50498   119658    60621
# 11   185300    84396   181653    86129   189634    81950   194905    90765
# 12   364495   169436   430154   202218   286485   126386   336275   166784
# 13   130763   113416   145554   128833   113190    92373   128323   111868
# 14   173340    88211   198751   112801   143148    60758   189363    99731
# ...

# %%
b=df_2.astype(float)

# %%
c=pd.concat([df, df_2], axis = 1)
c
# Out:
#              가계지출항목별(1)     2017   2017.1   2017.2   2017.3   2017.4   2017.5  \
# 4              가계지출 (원)  3396121  2831945  3877093  3350386  2824671  2208029
# 5              소비지출 (원)  2618489  2193344  2913063  2487285  2268500  1773219
# 6    01.식료품 · 비주류음료 (원)   386832   333391   385818   341315   388038   322159
# 7        02.주류 · 담배 (원)    35234    28339    39767    30970    29848    24290
# 8        03.의류 · 신발 (원)   162128   117249   186115   134377   133629    92576
# 9   04.주거 · 수도 · 광열 (원)   289762   212039   303247   221408   273741   199097
# 10  05.가정용품 · 가사서비스 (원)   117049    59087   132449    66084    98751    50498
# 11            06.보건 (원)   185300    84396   181653    86129   189634    81950
# 12            07.교통 (원)   364495   169436   430154   202218   286485   126386
# 13            08.통신 (원)   130763   113416   145554   128833   113190    92373
# 14       09.오락 · 문화 (원)   173340    88211   198751   112801   143148    60758
# ...

# %%
z=b.iloc[4]
z
# Out:
# 2017      162128.0
# 2017.1    117249.0
# 2017.2    186115.0
# 2017.3    134377.0
# 2017.4    133629.0
# 2017.5     92576.0
# 2018      153481.0
# 2018.1    112424.0
# 2018.2    176321.0
# 2018.3    129980.0
# 2018.4    124227.0
# 2018.5     87114.0
# Name: 8, dtype: float64

# %%
plt.plot(b.iloc[4])
plt.show()
##가계지출 (원)

# %%
plt.plot(b.iloc[5])
plt.show()
##소비지출 (원)

# %%
kf=kf.drop(index=0,axis=0)

kf
# Out:
#             가계수지항목별 2019.1/4 2019.1/4.1 2019.1/4.2 2019.2/4 2019.2/4.1  \
# 1          가구원수 (명)     2.42       2.61       2.18     2.41       2.56
# 2         가구주연령 (세)    52.20      46.71      59.57    52.15      47.60
# 3          가구분포 (%)   100.00      57.28      42.72   100.00      59.72
# 4                소득  4271911    5219758    3000893  4168865    4890840
# 5              경상소득  4187631    5142679    2906957  4111302    4845590
# 6              근로소득  2767115    4448305     512720  2715584    4196454
# 7              사업소득   774345     191951    1555308   833315     228785
# 8              재산소득    34095      30432      39008    45210      50009
# 9              이전소득   612075     471991     799921   517194     370343
# 10            비경상소득    84280      77079      93936    57563      45249
# 11             가계지출  3458752    4027578    2695984  3191378    3653718
# 12             소비지출  2544919    2876669    2100058  2357094    2615437
# ...

# %%
kf=kf.drop(index=1,axis=0)
kf
# Out:
#             가계수지항목별 2019.1/4 2019.1/4.1 2019.1/4.2 2019.2/4 2019.2/4.
# 4   4271911.0   5219758.0   3000893.0  4168865.0   4890840.0   3098305.0
# 5   4187631.0   5142679.0   2906957.0  4111302.0   4845590.0   3022483.0
# 6   2767115.0   4448305.0    512720.0  2715584.0   4196454.0    519716.0
# 7    774345.0    191951.0   1555308.0   833315.0    228785.0   1729726.0
# 8     34095.0     30432.0     39008.0    45210.0     50009.0     38093.0
# 9    612075.0    471991.0    799921.0   517194.0    370343.0    734948.0
# 10    84280.0     77079.0     93936.0    57563.0     45249.0     75822.0
# 11  3458752.0   4027578.0   2695984.0  3191378.0   3653718.0   2505810.0
# 12  2544919.0   2876669.0   2100058.0  2357094.0   2615437.0   1974017.0
# 13   330884.0    346139.0    310426.0   308864.0    322744.0    288281.0
# 14    36489.0     40141.0     31592.0    35550.0     38418.0     31297.0
# 15   134719.0    160770.0     99787.0   144409.0    169193.0    107658.0
# ...

# %%
b_1.iloc[11]
# Out:
# 2019.1/4      134719.0
# 2019.1/4.1    160770.0
# 2019.1/4.2     99787.0
# 2019.2/4      144409.0
# 2019.2/4.1    169193.0
# 2019.2/4.2    107658.0
# 2019.3/4      111399.0
# 2019.3/4.1    128978.0
# 2019.3/4.2     86236.0
# 2019.4/4      163304.0
# 2019.4/4.1    186919.0
# 2019.4/4.2    128743.0
# 2020.1/4       97489.0
# 2020.1/4.1    115958.0
# 2020.1/4.2     72682.0
# 2020.2/4      134561.0
# 2020.2/4.1    159074.0
# 2020.2/4.2    101646.0
# 2020.3/4       96306.0
# 2020.3/4.1    112780.0
# 2020.3/4.2     73142.0
# 2020.4/4      143790.0
# 2020.4/4.1    168008.0
# 2020.4/4.2    109173.0
# 2021.1/4      106509.0
# 2021.1/4.1    126516.0
# 2021.1/4.2     80199.0
# 2021.2/4      128920.0
# 2021.2/4.1    148467.0
# 2021.2/4.2    100177.0
# 2021.3/4      105894.0
# 2021.3/4.1    122581.0
# 2021.3/4.2     81340.0
# 2021.4/4      161273.0
# 2021.4/4.1    184455.0
# 2021.4/4.2    127876.0
# 2022.1/4      112625.0
# 2022.1/4.1    132673.0
# 2022.1/4.2     84247.0
# 2022.2/4      144980.0
# ...

# %%
plt.plot(b_1.iloc[11])
plt.show()
##가계지출 (원)

# %%
plt.plot(b_1.iloc[12])
plt.show()

# %%
plt.plot(b.iloc[4],'r')
plt.plot(b_1.iloc[11],'g')
plt.show()

# %%
plt.plot(b.iloc[5],'r')
plt.plot(b_1.iloc[12],'g')
plt.show()

# %%
plt.plot(b.iloc[13],'r')
plt.plot(b_1.iloc[20],'g')
plt.show()

# %%
a=b.iloc[4]
a
# Out:
# 2017      162128.0
# 2017.1    117249.0
# 2017.2    186115.0
# 2017.3    134377.0
# 2017.4    133629.0
# 2017.5     92576.0
# 2018      153481.0
# 2018.1    112424.0
# 2018.2    176321.0
# 2018.3    129980.0
# 2018.4    124227.0
# 2018.5     87114.0
# Name: 8, dtype: float64

# %%
b_a=b_1.iloc[11]

# %%
ab_0=pd.concat([a, b_a])
ab_0
# Out:
# 2017          162128.0
# 2017.1        117249.0
# 2017.2        186115.0
# 2017.3        134377.0
# 2017.4        133629.0
# 2020.1/4.1    226585.0
# 2020.1/4.2    179965.0
# 2020.2/4      206759.0
# 2020.2/4.1    223994.0
# 2020.2/4.2    183616.0
# 2020.3/4      198641.0
# 2020.3/4.1    216594.0
# 2020.3/4.2    173397.0
# 2020.4/4      204260.0
# 2020.4/4.1    216710.0
# 2020.4/4.2    186464.0
# 2021.1/4      195033.0
# 2021.1/4.1    216217.0
# 2021.1/4.2    167175.0
# 2021.2/4      207128.0
# ...

# %%
plt.plot(ab_0,'r',label = "household expenditure")
plt.plot(ab_1,'g',label = "consumer expenditure")
plt.plot(ab_2,'b',label = "food and accommodation")
plt.legend()
plt.show()

# %%
 korea1718_db = pd.read_csv("../Downloads/가구특성별_소득원천별_가구소득_20221024020052.csv", encoding="cp949")
 gh= korea1718_db
 gh
# Out:
#                        가구특성별     원천별               2017              2017.1  \
# 0                      가구특성별     원천별  가구소득(전년도) 평균 (만원)  가구소득(전년도) 중앙값 (만원)
# 1                         전체    경상소득               5478                4300
# 2                         전체    근로소득               3499                   -
# 3                         전체    사업소득               1217                   -
# 4                         전체    재산소득                353                   -
# 5                         전체  공적이전소득                328                   -
# 6                         전체  사적이전소득                 81                   -
# 7                 (가구주 성) 남자    경상소득               6219                5032
# 8                 (가구주 성) 남자    근로소득               4022                   -
# 9                 (가구주 성) 남자    사업소득               1408                   -
# 10                (가구주 성) 남자    재산소득                398                   -
# ...

# %%
gh.drop(0)
# Out:
#                        가구특성별     원천별  2017 2017.1   2018 2018.1   2019 2019.1  \
# 1                         전체    경상소득  5478   4300   5705   4457   5828   4567
# 2                         전체    근로소득  3499      -   3640      -   3781      -
# 3                         전체    사업소득  1217      -   1243      -   1177      -
# 4                         전체    재산소득   353      -    380      -    380      -
# 5                         전체  공적이전소득   328      -    351      -    387      -
# 6                         전체  사적이전소득    81      -     91      -    102      -
# 7                 (가구주 성) 남자    경상소득  6219   5032   6479   5184   6639   5351
# 8                 (가구주 성) 남자    근로소득  4022      -   4181      -   4363      -
# 9                 (가구주 성) 남자    사업소득  1408      -   1443      -   1373      -
# 10                (가구주 성) 남자    재산소득   398      -    430      -    431      -
# 11                (가구주 성) 남자  공적이전소득   329      -    354      -    390      -
# ...

# %%
gh=gh.drop(['가구특성별'], axis = 1)

gh
# Out:
#         원천별               2017              2017.1               2018  \
# 0       원천별  가구소득(전년도) 평균 (만원)  가구소득(전년도) 중앙값 (만원)  가구소득(전년도) 평균 (만원)
# 1      경상소득               5478                4300               5705
# 2      근로소득               3499                   -               3640
# 3      사업소득               1217                   -               1243
# 4      재산소득                353                   -                380
# 5    공적이전소득                328                   -                351
# 6    사적이전소득                 81                   -                 91
# 7      경상소득               6219                5032               6479
# 8      근로소득               4022                   -               4181
# 9      사업소득               1408                   -               1443
# 10     재산소득                398                   -                430
# 11   공적이전소득                329                   -                354
# ...

# %%
gh=gh.drop(['원천별'], axis = 1)

gh
# Out:
#                   2017              2017.1               2018  \
# 0    가구소득(전년도) 평균 (만원)  가구소득(전년도) 중앙값 (만원)  가구소득(전년도) 평균 (만원)
# 1                 5478                4300               5705
# 2                 3499                   -               3640
# 3                 1217                   -               1243
# 4                  353                   -                380
# 5                  328                   -                351
# 6                   81                   -                 91
# 7                 6219                5032               6479
# 8                 4022                   -               4181
# 9                 1408                   -               1443
# 10                 398                   -                430
# 11                 329                   -                354
# 12                  62                   -                 71
# 13                2923                1891               2986
# ...

# %%
al=gh.drop(0)
al
# Out:
#      2017 2017.1   2018 2018.1   2019 2019.1   2020 2020.1   2021 2021.1
# 1    5478   4300   5705   4457   5828   4567   5924   4652   6125   4836
# 2    3499      -   3640      -   3781      -   3791      -   3855      -
# 3    1217      -   1243      -   1177      -   1151      -   1135      -
# 4     353      -    380      -    380      -    417      -    432      -
# 5     328      -    351      -    387      -    457      -    602      -
# 6      81      -     91      -    102      -    107      -    101      -
# 7    6219   5032   6479   5184   6639   5351   6791   5523   6997   5769
# 8    4022      -   4181      -   4363      -   4411      -   4470      -
# 9    1408      -   1443      -   1373      -   1355      -   1330      -
# 10    398      -    430      -    431      -    476      -    500      -
# 11    329      -    354      -    390      -    465      -    620      -
# 12     62      -     71      -     82      -     83      -     77      -
# ...

# %%
len(al)
# Out:
# 240

# %%
k
for each in range(0,240):
    if each%6==0:
        al.iloc[each]
        k.append(al.iloc[each])
        print(al.iloc[each])
# Out:
# 2017      5478
# 2017.1    4300
# 2018      5705
# 2018.1    4457
# 2019      5828
# 2019.1    4567
# 2020      5924
# 2020.1    4652
# 2021      6125
# 2021.1    4836
# Name: 1, dtype: object
# 2017      6219
# 2017.1    5032
# 2018      6479
# 2018.1    5184
# 2019      6639
# 2019.1    5351
# 2020      6791
# 2020.1    5523
# 2021      6997
# 2021.1    5769
# Name: 7, dtype: object
# 2017      2923
# 2017.1    1891
# 2018      2986
# 2018.1    1965
# 2019      3052
# 2019.1    2044
# 2020      3085
# 2020.1    2112
# 2021      3348
# 2021.1    2426
# Name: 13, dtype: object
# 2017      5166
# 2017.1    4509
# 2018      5444
# 2018.1    4796
# 2019      5670
# 2019.1    4969
# 2020      5935
# 2020.1    5113
# 2021      6177
# 2021.1    5220
# Name: 19, dtype: object
# 2017      3270
# 2017.1    2787
# 2018      3533
# 2018.1    3030
# 2019      3720
# 2019.1    3363
# 2020      3533
# 2020.1    2962
# 2021      3648
# 2021.1    3068
# Name: 25, dtype: object
# 2017      5485
# ...

# %%
k
# Out:
# [2017      5478
#  2017.1    4300
#  2018      5705
#  2018.1    4457
#  2019      5828
#  2019.1    4567
#  2020      5924
#  2020.1    4652
#  2021      6125
#  2021.1    4836
#  Name: 1, dtype: object,
#  2017      6219
#  2017.1    5032
#  2018      6479
#  2018.1    5184
#  2019      6639
#  2019.1    5351
#  2020      6791
#  2020.1    5523
#  2021      6997
#  2021.1    5769
#  Name: 7, dtype: object,
#  2017      2923
#  2017.1    1891
#  2018      2986
#  2018.1    1965
#  2019      3052
#  2019.1    2044
#  2020      3085
#  2020.1    2112
#  2021      3348
#  2021.1    2426
#  Name: 13, dtype: object,
#  2017      5166
#  2017.1    4509
#  2018      5444
#  2018.1    4796
#  2019      5670
#  2019.1    4969
#  2020      5935
#  2020.1    5113
#  2021      6177
#  2021.1    5220
#  Name: 19, dtype: object,
#  2017      3270
#  2017.1    2787
#  2018      3533
#  2018.1    3030
#  2019      3720
#  2019.1    3363
#  2020      3533
#  2020.1    2962
#  2021      3648
# ...

# %%
len(k)
# Out:
# 640

# %%
a=[]
for each in range(40):
    abc=k[each].astype(float)
    a.append(abc)

# %%
for each in range(40):
    t=a[each]*10000
    print(t)
# Out:
# 2017      54780000.0
# 2017.1    43000000.0
# 2018      57050000.0
# 2018.1    44570000.0
# 2019      58280000.0
# 2019.1    45670000.0
# 2020      59240000.0
# 2020.1    46520000.0
# 2021      61250000.0
# 2021.1    48360000.0
# Name: 1, dtype: float64
# 2017      62190000.0
# 2017.1    50320000.0
# 2018      64790000.0
# 2018.1    51840000.0
# 2019      66390000.0
# 2019.1    53510000.0
# 2020      67910000.0
# 2020.1    55230000.0
# 2021      69970000.0
# 2021.1    57690000.0
# Name: 7, dtype: float64
# 2017      29230000.0
# 2017.1    18910000.0
# 2018      29860000.0
# 2018.1    19650000.0
# 2019      30520000.0
# 2019.1    20440000.0
# 2020      30850000.0
# 2020.1    21120000.0
# 2021      33480000.0
# 2021.1    24260000.0
# Name: 13, dtype: float64
# 2017      51660000.0
# 2017.1    45090000.0
# 2018      54440000.0
# 2018.1    47960000.0
# 2019      56700000.0
# 2019.1    49690000.0
# 2020      59350000.0
# 2020.1    51130000.0
# 2021      61770000.0
# 2021.1    52200000.0
# ...

# %%
plt.plot(ab_0,'r',label = "household expenditure")
plt.plot(ab_1,'g',label = "consumer expenditure")
plt.plot(ab_2,'b',label = "food and accommodation")
plt.legend()
plt.show()

# %%
plt.plot(a[0],'c',label = "ordinary income")

# %%
y[1]=[722040,437565,33138,377549]
y[2]=[123246556,62384451,4762919,48387770]
y[3]=[4303814,3511447,283989,3575877]
y[0]=[60526526,5980594,81815751,147841992]

# %%
plt.plot(x, y[0],'r', label = "Supply")

plt.plot(x, y[1],'b',label = "navigation")


plt.plot(x, y[2],'g',label = "passenger")
plt.plot(x, y[3],'k',label = "Cargo")
plt.legend()

plt.show()

# %%
import folium
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option("display.max_rows", None)
pd.set_option('display.max_columns', None)
seoul_db = pd.read_csv("../Downloads/지역별 숙박 소계.csv", encoding="utf-8")
af = seoul_db
af
# Out:
#               서울     관광사업체     관광사업체(2)  관광사업체(3) 관광사업체(4)     항목     단위  \
# 0             합계       여행업           일반        일반       일반     항목    NaN
# 1             합계       여행업           국외        국외       국외     항목    NaN
# 2             합계       여행업           국내        국내       국내     항목    NaN
# 3             부산      2017         2017      2017     2017   2017   2017
# 4         구군별(1)       여행업          여행업       여행업      여행업  관광숙박업  관광숙박업
# 5         구군별(1)        일반           국외        국내   국내외여행업  가족호텔업  관광호텔업
# 6             합계       177          765       554      439      1     79
# 7             대구      2017         2017      2017     2017   2017   2017
# 8   행정구역(구군)별(1)       여행업          여행업       여행업      여행업  관광숙박업  관광숙박업
# 9   행정구역(구군)별(1)        일반           국외        국내   국내외여행업  관광호텔업  기타호텔업
# 10            합계       109           82        52      345     23      3
# 11            인천      2017         2017      2017     2017   2017   2017
# ...

# %%
seoul=af[:3]

# %%
busan=af[3:7]
busan
# Out:
Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14  \
# 17        2020   2020        2020        2020        2020        2020
# 18    관광객이용시설업  국제회의업       국제회의업       유원시설업       유원시설업       유원시설업
# 19  외국인관광도시민박업    시설업         기획업     종합유원시설업     일반유원시설업     기타유원시설업
# 20          24      1          24           1           4          50
#
#    Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 17        2020        2020        2020        2020         NaN         NaN
# 18     관광편의시설업     관광편의시설업     관광편의시설업     관광편의시설업         NaN         NaN
# ...

# %%
daejeon=af[21:52]
daejeon
# Out:
#      서울     관광사업체     관광사업체(2)  관광사업체(3) 관광사업체(4)    항목    단위 2017 년 2018 년  \
# 21   대전  관광산업별(1)     관광산업별(2)  관광산업별(3)     2017  2018  2019   2020    NaN
# 22   합계       여행업           일반        소계       80    88    90     93    NaN
# 23  NaN       NaN           국외        소계      256   271   260    257    NaN
# 24  NaN       NaN           국내        소계      224   234   222    229    NaN
# 25  NaN     관광숙박업          호텔업     가족호텔업        1     1     1      1    NaN
# 26  NaN       NaN          NaN     관광호텔업       19    16    16     16    NaN
# 27  NaN       NaN          NaN     기타호텔업        -     -     -      -    NaN
# 28  NaN       NaN     휴양콘도미니엄업        소계        -     -     -      -    NaN
# 29  NaN  관광객이용시설업        전문휴양업        소계        1     1     1      1    NaN
# 30  NaN       NaN        종합휴양업        소계        1     1     1      1    NaN
# 31  NaN       NaN         야영장업        소계        3     7     7      9    NaN
# ...

# %%
san=af[52:56]
san
# Out:
#               서울 관광사업체 관광사업체(2) 관광사업체(3) 관광사업체(4)     항목     단위 2017 년  \
# 52            울산  2017     2017     2017     2017   2017   2017   2017
# 53  행정구역(구군)별(1)   여행업      여행업      여행업      여행업  관광숙박업  관광숙박업  관광숙박업
# 54  행정구역(구군)별(1)    일반       국외       국내   국내외여행업  가족호텔업  관광호텔업  기타호텔업
# 55            합계    29      141      139        -      1     12      -
#
#       2018 년    2019 년    2020 년 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 52      2017      2017      2017        2017        2017        2017
# 53     관광숙박업  관광객이용시설업  관광객이용시설업    관광객이용시설업    관광객이용시설업    관광객이용시설업
# 54  휴양콘도미니엄업     전문휴양업     종합휴양업     자동차야영장업      관광유람선업      관광공연장업
# 55         -         -         -           7           -           -
#
#       Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 52           2017        2017        2017        2017        2017        2017
# 53       관광객이용시설업    관광객이용시설업       국제회의업       국제회의업        카지노업       유원시설업
# ...

# %%
jaeju=af[56:94]

# %%
seoul_0=[2938,3009,3555,3394]

# %%
seoul_1=[3612,3834,3552,3290]

# %%
seoul_2=[1318,2055,1216,1242]
x=['2017','2018','2019','2020']

# %%
plt.plot(x, seoul_0,'b')

# %%
plt.plot(x, seoul_1,'b')

# %%
plt.plot(x, seoul_2,'b')

# %%
busan_0=[177,219,248,254]

# %%
busan_1=[765,769,785,757]

# %%
busan_2=[554,547,575,565]

# %%
plt.plot(x, busan_0,'b')

# %%
plt.plot(x, busan_1,'b')

# %%
plt.plot(x, busan_2,'b')

# %%
daegu_0=[109,123,128,136]

# %%
daegu_1=[82,88,431,417]

# %%
daegu_2=[52,47,383,378]

# %%
plt.plot(x, daegu_0,'b')

# %%
plt.plot(x, daegu_1,'b')

# %%
plt.plot(x, daegu_2,'b')

# %%
incheon_0=[88,106,114,113]

# %%
incheon_1=[283,301,305,288]

# %%
incheon_2=[251,257,254,250]

# %%
plt.plot(x, incheon_0,'b')

# %%
plt.plot(x, incheon_1,'b')

# %%
plt.plot(x, incheon_2,'b')

# %%
daejeon_0=[80,88,90,93]

# %%
daejeon_1=[256,271,260,257]

# %%
daejeon_2=[224,234,222,229]

# %%
plt.plot(x, daejeon_0,'b')

# %%
plt.plot(x, daejeon_1,'b')

# %%
plt.plot(x, daejeon_2,'b')

# %%
san_0=[29,44,48,53]

# %%
san_1=[141,156,152,141]

# %%
san_2=[139,149,145,137]

# %%
plt.plot(x, san_0,'b')

# %%
plt.plot(x, san_1,'b')

# %%
plt.plot(x, san_2,'b')

# %%
jaeju_0=[329,347,366,348]

# %%
jaeju_1=[141,145,147,133]

# %%
jaeju_2=[639,627,610,589]

# %%
plt.plot(x, jaeju_0,'b')

# %%
plt.plot(x, jaeju_1,'b')

# %%
plt.plot(x, jaeju_2,'b')

# %%
y_seoul=[seoul_0,seoul_1,seoul_2]
print(y_seoul)
# Out:
# [[2938, 3009, 3555, 3394], [3612, 3834, 3552, 3290], [1318, 2055, 1216, 1242]]

# %%
plt.plot(x,seoul_0)
plt.plot(x,seoul_1)
plt.plot(x,seoul_2)
plt.show()

# %%
plt.plot(x,busan_0)
plt.plot(x,busan_1)
plt.plot(x,busan_2)
plt.show()

# %%
plt.plot(x,daegu_0)
plt.plot(x,daegu_1)
plt.plot(x,daegu_2)
plt.show()

# %%
plt.plot(x,incheon_0)
plt.plot(x,incheon_1)
plt.plot(x,incheon_2)
plt.show()

# %%
plt.plot(x,daejeon_0)
plt.plot(x,daejeon_1)
plt.plot(x,daejeon_2)
plt.show()

# %%
plt.plot(x,san_0)
plt.plot(x,san_1)
plt.plot(x,san_2)
plt.show()

# %%
plt.plot(x,jaeju_0)
plt.plot(x,jaeju_1)
plt.plot(x,jaeju_2)
plt.show()

# %%
y_seoul
y_busan=[busan_0,busan_1,busan_2]
y_daegu=[daegu_0,daegu_1,daegu_2]
y_incheon=[incheon_0,incheon_1,incheon_2]
y_daejeon=[daejeon_0,daejeon_1,daejeon_2]
y_san=[san_0,san_1,san_2]
y_jaeju=[jaeju_0,jaeju_1,jaeju_2]
# Out:
# [[2938, 3009, 3555, 3394], [3612, 3834, 3552, 3290], [1318, 2055, 1216, 1242]]

# %%
from pandas import Series, DataFrame
korea_seoul= pd.DataFrame(y_seoul)
korea_busan= pd.DataFrame(y_busan)
korea_incheon= pd.DataFrame(y_incheon)
korea_daegu= pd.DataFrame(y_daegu)
korea_san= pd.DataFrame(y_san)
korea_jaeju= pd.DataFrame(y_jaeju)
korea_daejeon= pd.DataFrame(y_daejeon)

# %%
korea=pd.concat([korea_seoul,korea_busan,korea_daegu,korea_incheon,korea_daejeon,korea_san,korea_jaeju])

# %%
korea_float=korea.astype(float)
korea_float
# Out:
#         0       1       2       3
# 0  2938.0  3009.0  3555.0  3394.0
# 1  3612.0  3834.0  3552.0  3290.0
# 2  1318.0  2055.0  1216.0  1242.0
# 0   177.0   219.0   248.0   254.0
# 1   765.0   769.0   785.0   757.0
# 2   554.0   547.0   575.0   565.0
# 0   109.0   123.0   128.0   136.0
# 1    82.0    88.0   431.0   417.0
# 2    52.0    47.0   383.0   378.0
# 0    88.0   106.0   114.0   113.0
# 1   283.0   301.0   305.0   288.0
# 2   251.0   257.0   254.0   250.0
# 0    80.0    88.0    90.0    93.0
# 1   256.0   271.0   260.0   257.0
# 2   224.0   234.0   222.0   229.0
# 0    29.0    44.0    48.0    53.0
# 1   141.0   156.0   152.0   141.0
# 2   139.0   149.0   145.0   137.0
# 0   329.0   347.0   366.0   348.0
# 1   141.0   145.0   147.0   133.0
# 2   639.0   627.0   610.0   589.0

# %%
date = [2017,2018,2019,2020]

korea_list_0_00=((korea_float.loc[0][1]-korea_float.loc[0][0])/korea_float.loc[0][0])*100
korea_list_0_01=((korea_float.loc[0][2]-korea_float.loc[0][1])/korea_float.loc[0][1])*100
korea_list_0_02=((korea_float.loc[0][3]-korea_float.loc[0][2])/korea_float.loc[0][2])*100

# %%
korea_list_0_10=((korea_float.loc[1][1]-korea_float.loc[1][0])/korea_float.loc[1][0])*100
korea_list_0_11=((korea_float.loc[1][2]-korea_float.loc[1][1])/korea_float.loc[1][1])*100
korea_list_0_12=((korea_float.loc[1][3]-korea_float.loc[1][2])/korea_float.loc[1][2])*100

# %%
korea_list_0_20=((korea_float.loc[2][1]-korea_float.loc[2][0])/korea_float.loc[2][0])*100
korea_list_0_21=((korea_float.loc[2][2]-korea_float.loc[2][1])/korea_float.loc[2][1])*100
korea_list_0_22=((korea_float.loc[2][3]-korea_float.loc[2][2])/korea_float.loc[2][2])*100

# %%
korea_list=pd.concat([korea_list_0_00,korea_list_0_01,korea_list_0_02,
                      korea_list_0_10,korea_list_0_11,korea_list_0_12,
                      korea_list_0_20,korea_list_0_21,korea_list_0_22])

# %%
korea_list
# Out:
# 0      2.416610
# 0     23.728814
# 0     12.844037
# 0     20.454545
# 0     10.000000
# 0     51.724138
# 0      5.471125
# 0     18.145563
# 0     13.242009
# 0      4.065041
# 0      7.547170
# 0      2.272727
# 0      9.090909
# 0      5.475504
# 0     -4.528833
# 0      2.419355
# 0      6.250000
# 0     -0.877193
# 0      3.333333
# 0     10.416667
# 0     -4.918033
# 1      6.146179
# 1      0.522876
# 1      7.317073
# 1      6.360424
# 1      5.859375
# 1     10.638298
# 1      2.836879
# 1     -7.355243
# 1      2.080624
# 1    389.772727
# 1      1.328904
# 1     -4.059041
# 1     -2.564103
# 1      1.379310
# 1     -7.376126
# 1     -3.566879
# 1     -3.248260
# 1     -5.573770
# 1     -1.153846
# 1     -7.236842
# 1     -9.523810
# 2     55.918058
# 2     -1.263538
# 2     -9.615385
# 2      2.390438
# 2      4.464286
# 2      7.194245
# 2     -1.877934
# 2    -40.827251
# 2      5.118830
# 2    714.893617
# 2     -1.167315
# 2     -5.128205
# 2     -2.684564
# ...

# %%
korea_list_0_22
# Out:
# 2    2.138158
# 2   -1.739130
# 2   -1.305483
# 2   -1.574803
# 2    3.153153
# 2   -5.517241
# 2   -3.442623
# dtype: float64

# %%
korea_list_1819=[korea_list_0_20,korea_list_0_21,korea_list_0_22]

# %%
from tabulate import tabulate

list_1920_22 = [ ["서울",    2.138158],
     ["부산",  -1.739130],
     ["대구", -1.305483],
    ["인천",  -1.574803],
    ["대전",3.153153],
    ["울산",-5.517241],
    ["제주", -3.442623]]

# %%
list_1920_22
# Out:
# [['서울', 2.138158],
#  ['부산', -1.73913],
#  ['대구', -1.305483],
#  ['인천', -1.574803],
#  ['대전', 3.153153],
#  ['울산', -5.517241],
#  ['제주', -3.442623]]

# %%
(tabulate(list_1718_1, headers=['1718']))
# Out:
# '               1718\n--  ----  ---------\n 0  서울   6.14618\n 1  부산   0.522876\n 2  대구   7.31707\n 3  인천  -0.877193\n 4  대전   5.85938\n 5  울산  10.6383\n 6  제주  10.6383'

# %%
df_1718_0 = pd.DataFrame(list_1718_0, columns = ["지역",'1718'])
print(df_1718_0)
# Out:
#    지역       1718
# 0  서울   2.416610
# 1  부산  23.728814
# 2  대구  12.844037
# 3  인천  20.454545
# 4  대전  10.000000
# 5  울산  51.724138
# 6  제주   5.471125

# %%
list_1920_0 = pd.DataFrame(list_1920_0, columns = ["지역",'1920'])
print(list_1920_0)
# Out:
#    지역       1920
# 0  서울  -4.528833
# 1  부산   2.419355
# 2  대구   6.250000
# 3  인천  -0.877193
# 4  대전   3.333333
# 5  울산  10.416667
# 6  제주  -4.918033

# %%
list_1819_0
# Out:
#    지역       1819
# 0  서울   2.416610
# 1  부산  18.145563
# 2  대구  13.242009
# 3  인천   4.065041
# 4  대전   7.547170
# 5  울산   9.090909
# 6  제주   5.475504

# %%
list_1718_10=pd.DataFrame(list_1718_10, columns = ["지역",'1718'])
print(list_1718_10)
# Out:
#    지역       1718
# 0  서울   6.146179
# 1  부산   0.522876
# 2  대구   7.317073
# 3  인천  -0.877193
# 4  대전   5.859375
# 5  울산  10.638298
# 6  제주  10.638298

# %%
list_1819_11=pd.DataFrame(list_1819_11, columns = ["지역",'1819'])
print(list_1819_11)
# Out:
#    지역        1819
# 0  서울   -7.355243
# 1  부산    2.080624
# 2  대구  389.772727
# 3  인천    1.328904
# 4  대전   -4.059041
# 5  울산   -2.564103
# 6  제주    1.379310

# %%
list_1920_12=pd.DataFrame(list_1920_12, columns = ["지역",'1920'])
print(list_1920_12)
# Out:
#    지역      1920
# 0  서울 -7.376126
# 1  부산 -3.566879
# 2  대구 -3.248260
# 3  인천 -5.573770
# 4  대전 -1.153846
# 5  울산 -7.236842
# 6  제주 -9.523810

# %%
list_1718_20=pd.DataFrame(list_1718_20, columns = ["지역",'1718'])
print(list_1718_20)
# Out:
#    지역       1718
# 0  서울  55.918058
# 1  부산  -1.263538
# 2  대구  -9.615385
# 3  인천   2.390438
# 4  대전   4.464286
# 5  울산   7.194245
# 6  제주  -1.877934

# %%
list_1819_21 =pd.DataFrame(list_1819_21 , columns = ["지역",'1819'])
print(list_1819_21 )
# Out:
#    지역        1819
# 0  서울  -40.827251
# 1  부산    5.118830
# 2  대구  714.893617
# 3  인천   -1.167315
# 4  대전   -5.128205
# 5  울산   -2.684564
# 6  제주   -2.711324

# %%
list_1920_22 =pd.DataFrame(list_1920_22 , columns = ["지역",'1920'])
print(list_1920_22 )
# Out:
#    지역      1920
# 0  서울  2.138158
# 1  부산 -1.739130
# 2  대구 -1.305483
# 3  인천 -1.574803
# 4  대전  3.153153
# 5  울산 -5.517241
# 6  제주 -3.442623

# %%
df_1718_0
# Out:
#    지역       1718
# 0  서울   2.416610
# 1  부산  23.728814
# 2  대구  12.844037
# 3  인천  20.454545
# 4  대전  10.000000
# 5  울산  51.724138
# 6  제주   5.471125

# %%
list_1819_0
# Out:
#    지역       1819
# 0  서울   2.416610
# 1  부산  18.145563
# 2  대구  13.242009
# 3  인천   4.065041
# 4  대전   7.547170
# 5  울산   9.090909
# 6  제주   5.475504

# %%
list_1920_0
# Out:
#    지역       1920
# 0  서울  -4.528833
# 1  부산   2.419355
# 2  대구   6.250000
# 3  인천  -0.877193
# 4  대전   3.333333
# 5  울산  10.416667
# 6  제주  -4.918033

# %%
korea_sum_0=pd.concat([df_1718_0,list_1819_0,list_1920_0],axis=1, join='inner')

# %%
korea_sum_0
# Out:
#    지역       1718  지역       1819  지역       1920
# 0  서울   2.416610  서울   2.416610  서울  -4.528833
# 1  부산  23.728814  부산  18.145563  부산   2.419355
# 2  대구  12.844037  대구  13.242009  대구   6.250000
# 3  인천  20.454545  인천   4.065041  인천  -0.877193
# 4  대전  10.000000  대전   7.547170  대전   3.333333
# 5  울산  51.724138  울산   9.090909  울산  10.416667
# 6  제주   5.471125  제주   5.475504  제주  -4.918033

# %%
korea_sum_1=pd.concat([list_1718_10,list_1819_11,list_1920_12],axis=1, join='inner')

# %%
korea_sum_1
# Out:
#    지역       1718  지역        1819  지역      1920
# 0  서울   6.146179  서울   -7.355243  서울 -7.376126
# 1  부산   0.522876  부산    2.080624  부산 -3.566879
# 2  대구   7.317073  대구  389.772727  대구 -3.248260
# 3  인천  -0.877193  인천    1.328904  인천 -5.573770
# 4  대전   5.859375  대전   -4.059041  대전 -1.153846
# 5  울산  10.638298  울산   -2.564103  울산 -7.236842
# 6  제주  10.638298  제주    1.379310  제주 -9.523810

# %%
korea_sum_2=pd.concat([list_1718_20,list_1819_21,list_1920_22],axis=1, join='inner')

# %%
korea_sum_2
# Out:
#    지역       1718  지역        1819  지역      1920
# 0  서울  55.918058  서울  -40.827251  서울  2.138158
# 1  부산  -1.263538  부산    5.118830  부산 -1.739130
# 2  대구  -9.615385  대구  714.893617  대구 -1.305483
# 3  인천   2.390438  인천   -1.167315  인천 -1.574803
# 4  대전   4.464286  대전   -5.128205  대전  3.153153
# 5  울산   7.194245  울산   -2.684564  울산 -5.517241
# 6  제주  -1.877934  제주   -2.711324  제주 -3.442623

# %%
# Out:
# 지역            서울
# 1718     2.41661
# 지역            서울
# 1819     2.41661
# 지역            서울
# 1920   -4.528833
# Name: 0, dtype: object
