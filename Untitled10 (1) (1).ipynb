# %%
import folium
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option("display.max_rows", None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# <h1> 만약 사공이 많다면 사람은 누구를 뽑을 까</h1>

# %%
raw_data =pd.read_excel('../Downloads/[제8회_전국동시지방선거]_개표단위별_개표결과.xlsx')
raw_data
# Out:
#               중앙선거관리위원회 선거통계시스템 Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4  \
# 0     [제8회 전국동시지방선거] 개표단위별 개표결과        NaN        NaN        NaN          NaN
# 1   [구·시·군의 장선거][경기도][안성시][안성시]        NaN        NaN        NaN          NaN
# 2                          읍면동명         구분       선거인수        투표수     후보자별 득표수
# 3                           NaN        NaN        NaN        NaN  더불어민주당\n김보라
# 4                          합계               163,518     81,762       40,497
# 5                        거소투표                   186        174           84
# 6                      관외사전투표                 9,920      9,915        5,267
# 7                         공도읍          계     45,735     18,902       10,679
# 8                         공도읍     관내사전투표      5,171      5,165        2,948
# 9                         공도읍      선거일투표     40,564     13,737        7,731
# 10                        보개면          계      4,835      2,827        1,243
# ...

# %%
kongdo=pd.concat([raw_data.iloc[7],raw_data.iloc[8],raw_data.iloc[9]],axis=1)
kongdo
# Out:
#                           7         8         9
# 중앙선거관리위원회 선거통계시스템     공도읍       공도읍       공도읍
# Unnamed: 1              계    관내사전투표     선거일투표
# Unnamed: 2         45,735     5,171    40,564
# Unnamed: 3         18,902     5,165    13,737
# Unnamed: 4         10,679     2,948     7,731
# Unnamed: 5              NaN       NaN       NaN
# Unnamed: 6          8,037     2,166     5,871
# Unnamed: 7         18,716     5,114    13,602
# Unnamed: 8            186        51       135
# Unnamed: 9         26,833         6    26,827

# %%
bogae=pd.concat([raw_data.iloc[10],raw_data.iloc[11],raw_data.iloc[12]],axis=1)
bogae
# Out:
#                         10        11       12
# 중앙선거관리위원회 선거통계시스템    보개면       보개면      보개면
# Unnamed: 1             계    관내사전투표    선거일투표
# Unnamed: 2         4,835     1,375    3,460
# Unnamed: 3         2,827     1,374    1,453
# Unnamed: 4         1,243       693      550
# Unnamed: 5             NaN       NaN      NaN
# Unnamed: 6         1,527       665      862
# Unnamed: 7         2,770     1,358    1,412
# Unnamed: 8            57        16       41
# Unnamed: 9         2,008         1    2,007

# %%
khumkwang=pd.concat([raw_data.iloc[13],raw_data.iloc[14],raw_data.iloc[15]],axis=1)
khumkwang
# Out:
#                         13        14       15
# 중앙선거관리위원회 선거통계시스템    금광면       금광면      금광면
# Unnamed: 1             계    관내사전투표    선거일투표
# Unnamed: 2         6,209       996    5,213
# Unnamed: 3         3,337       995    2,342
# Unnamed: 4         1,625       496    1,129
# Unnamed: 5             NaN       NaN      NaN
# Unnamed: 6         1,639       464    1,175
# Unnamed: 7         3,264       960    2,304
# Unnamed: 8            73        35       38
# Unnamed: 9         2,872         1    2,871

# %%
shoe=pd.concat([raw_data.iloc[16],raw_data.iloc[17],raw_data.iloc[18]],axis=1)
shoe
# Out:
#                         16        17       18
# 중앙선거관리위원회 선거통계시스템    서운면       서운면      서운면
# Unnamed: 1             계    관내사전투표    선거일투표
# Unnamed: 2         2,967       813    2,154
# Unnamed: 3         1,705       812      893
# Unnamed: 4           697       359      338
# Unnamed: 5             NaN       NaN      NaN
# Unnamed: 6           970       433      537
# Unnamed: 7         1,667       792      875
# Unnamed: 8            38        20       18
# Unnamed: 9         1,262         1    1,261

# %%
mi=pd.concat([raw_data.iloc[19],raw_data.iloc[20],raw_data.iloc[21]],axis=1)
mi
# Out:
#                         19        20       21
# 중앙선거관리위원회 선거통계시스템    미양면       미양면      미양면
# Unnamed: 1             계    관내사전투표    선거일투표
# Unnamed: 2         5,016       854    4,162
# Unnamed: 3         2,376       854    1,522
# Unnamed: 4           888       322      566
# Unnamed: 5             NaN       NaN      NaN
# Unnamed: 6         1,438       497      941
# Unnamed: 7         2,326       819    1,507
# Unnamed: 8            50        35       15
# Unnamed: 9         2,640         0    2,640

# %%
dae=pd.concat([raw_data.iloc[22],raw_data.iloc[23],raw_data.iloc[24]],axis=1)
dae
# Out:
#                          22        23        24
# 중앙선거관리위원회 선거통계시스템     대덕면       대덕면       대덕면
# Unnamed: 1              계    관내사전투표     선거일투표
# Unnamed: 2         12,517     1,648    10,869
# Unnamed: 3          5,065     1,644     3,421
# Unnamed: 4          2,567       884     1,683
# Unnamed: 5              NaN       NaN       NaN
# Unnamed: 6          2,419       726     1,693
# Unnamed: 7          4,986     1,610     3,376
# Unnamed: 8             79        34        45
# Unnamed: 9          7,452         4     7,448

# %%
yyang=pd.concat([raw_data.iloc[25],raw_data.iloc[26],raw_data.iloc[27]],axis=1)
yyang
# Out:
#                         25        26       27
# 중앙선거관리위원회 선거통계시스템    양성면       양성면      양성면
# Unnamed: 1             계    관내사전투표    선거일투표
# Unnamed: 2         4,544       951    3,593
# Unnamed: 3         2,453       951    1,502
# Unnamed: 4           843       353      490
# Unnamed: 5             NaN       NaN      NaN
# Unnamed: 6         1,564       567      997
# Unnamed: 7         2,407       920    1,487
# Unnamed: 8            46        31       15
# Unnamed: 9         2,091         0    2,091

# %%
won=pd.concat([raw_data.iloc[28],raw_data.iloc[29],raw_data.iloc[30]],axis=1)
won
# Out:
#                         28        29       30
# 중앙선거관리위원회 선거통계시스템    원곡면       원곡면      원곡면
# Unnamed: 1             계    관내사전투표    선거일투표
# Unnamed: 2         5,612       862    4,750
# Unnamed: 3         2,304       859    1,445
# Unnamed: 4           964       349      615
# Unnamed: 5             NaN       NaN      NaN
# Unnamed: 6         1,302       493      809
# Unnamed: 7         2,266       842    1,424
# Unnamed: 8            38        17       21
# Unnamed: 9         3,308         3    3,305

# %%
iill=pd.concat([raw_data.iloc[31],raw_data.iloc[32],raw_data.iloc[33]],axis=1)
iill
# Out:
#                         31        32       33
# 중앙선거관리위원회 선거통계시스템    일죽면       일죽면      일죽면
# Unnamed: 1             계    관내사전투표    선거일투표
# Unnamed: 2         6,534     1,562    4,972
# Unnamed: 3         3,441     1,560    1,881
# Unnamed: 4         1,184       564      620
# Unnamed: 5             NaN       NaN      NaN
# Unnamed: 6         2,151       917    1,234
# Unnamed: 7         3,335     1,481    1,854
# Unnamed: 8           106        79       27
# Unnamed: 9         3,093         2    3,091

# %%
juck=pd.concat([raw_data.iloc[34],raw_data.iloc[35],raw_data.iloc[36]],axis=1)
juck
# Out:
#                         34        35       36
# 중앙선거관리위원회 선거통계시스템    죽산면       죽산면      죽산면
# Unnamed: 1             계    관내사전투표    선거일투표
# Unnamed: 2         6,242     1,717    4,525
# Unnamed: 3         3,331     1,716    1,615
# Unnamed: 4         1,346       716      630
# Unnamed: 5             NaN       NaN      NaN
# Unnamed: 6         1,907       947      960
# Unnamed: 7         3,253     1,663    1,590
# Unnamed: 8            78        53       25
# Unnamed: 9         2,911         1    2,910

# %%
sam=pd.concat([raw_data.iloc[37],raw_data.iloc[38],raw_data.iloc[39]],axis=1)
sam
# Out:
#                         37        38       39
# 중앙선거관리위원회 선거통계시스템    삼죽면       삼죽면      삼죽면
# Unnamed: 1             계    관내사전투표    선거일투표
# Unnamed: 2         3,394       795    2,599
# Unnamed: 3         1,670       794      876
# Unnamed: 4           685       335      350
# Unnamed: 5             NaN       NaN      NaN
# Unnamed: 6           935       422      513
# Unnamed: 7         1,620       757      863
# Unnamed: 8            50        37       13
# Unnamed: 9         1,724         1    1,723

# %%
go=pd.concat([raw_data.iloc[40],raw_data.iloc[41],raw_data.iloc[42]],axis=1)
go
# Out:
#                         40        41       42
# 중앙선거관리위원회 선거통계시스템    고삼면       고삼면      고삼면
# Unnamed: 1             계    관내사전투표    선거일투표
# Unnamed: 2         1,857       580    1,277
# Unnamed: 3         1,198       580      618
# Unnamed: 4           501       249      252
# Unnamed: 5             NaN       NaN      NaN
# Unnamed: 6           648       299      349
# Unnamed: 7         1,149       548      601
# Unnamed: 8            49        32       17
# Unnamed: 9           659         0      659

# %%
an_1=pd.concat([raw_data.iloc[43],raw_data.iloc[44],raw_data.iloc[45]],axis=1)
an_1
# Out:
#                          43        44       45
# 중앙선거관리위원회 선거통계시스템    안성1동      안성1동     안성1동
# Unnamed: 1              계    관내사전투표    선거일투표
# Unnamed: 2         10,618     2,563    8,055
# Unnamed: 3          5,671     2,560    3,111
# Unnamed: 4          2,710     1,244    1,466
# Unnamed: 5              NaN       NaN      NaN
# Unnamed: 6          2,861     1,270    1,591
# Unnamed: 7          5,571     2,514    3,057
# Unnamed: 8            100        46       54
# Unnamed: 9          4,947         3    4,944

# %%
an_2=pd.concat([raw_data.iloc[46],raw_data.iloc[47],raw_data.iloc[48]],axis=1)
an_2
# Out:
#                          46        47        48
# 중앙선거관리위원회 선거통계시스템    안성2동      안성2동      안성2동
# Unnamed: 1              계    관내사전투표     선거일투표
# Unnamed: 2         20,006     3,391    16,615
# Unnamed: 3          8,957     3,383     5,574
# Unnamed: 4          4,869     1,898     2,971
# Unnamed: 5              NaN       NaN       NaN
# Unnamed: 6          3,979     1,441     2,538
# Unnamed: 7          8,848     3,339     5,509
# Unnamed: 8            109        44        65
# Unnamed: 9         11,049         8    11,041

# %%
an_3=pd.concat([raw_data.iloc[49],raw_data.iloc[50],raw_data.iloc[51]],axis=1)
an_3
# Out:
#                          49        50        51
# 중앙선거관리위원회 선거통계시스템    안성3동      안성3동      안성3동
# Unnamed: 1              계    관내사전투표     선거일투표
# Unnamed: 2         17,326     2,757    14,569
# Unnamed: 3          8,391     2,750     5,641
# Unnamed: 4          4,319     1,495     2,824
# Unnamed: 5              NaN       NaN       NaN
# Unnamed: 6          3,976     1,208     2,768
# Unnamed: 7          8,295     2,703     5,592
# Unnamed: 8             96        47        49
# Unnamed: 9          8,935         7     8,928

# %%
si_1=pd.concat([kongdo,yyang,won],axis=1)
si_1
# Out:
#                          7         8         9        25        26       27  \
# 중앙선거관리위원회 선거통계시스템     공도읍       공도읍       공도읍      양성면       양성면      양성면
# Unnamed: 1              계    관내사전투표     선거일투표        계    관내사전투표    선거일투표
# Unnamed: 2         45,735     5,171    40,564    4,544       951    3,593
# Unnamed: 3         18,902     5,165    13,737    2,453       951    1,502
# Unnamed: 4         10,679     2,948     7,731      843       353      490
# Unnamed: 5              NaN       NaN       NaN      NaN       NaN      NaN
# Unnamed: 6          8,037     2,166     5,871    1,564       567      997
# Unnamed: 7         18,716     5,114    13,602    2,407       920    1,487
# Unnamed: 8            186        51       135       46        31       15
# Unnamed: 9         26,833         6    26,827    2,091         0    2,091
#
#                         28        29       30
# 중앙선거관리위원회 선거통계시스템    원곡면       원곡면      원곡면
# Unnamed: 1             계    관내사전투표    선거일투표
# ...

# %%
drop_si_1=si_1.drop(["중앙선거관리위원회 선거통계시스템"]).drop(["Unnamed: 1"]).drop(["Unnamed: 5"])
drop_si_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Unnamed: 2 to Unnamed: 9
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   7       7 non-null      object
#  1   8       7 non-null      object
#  2   9       7 non-null      object
#  3   25      7 non-null      object
#  4   26      7 non-null      object
#  5   27      7 non-null      object
#  6   28      7 non-null      object
#  7   29      7 non-null      object
#  8   30      7 non-null      object
# dtypes: object(9)
# memory usage: 560.0+ bytes

# %%
si_1_0=drop_si_1.iloc[0]
si_1_1_0=drop_si_1.iloc[0].str.replace(',','').astype(int)
si_1_1=drop_si_1.iloc[1]
si_1_1_1=drop_si_1.iloc[1].str.replace(',','').astype(int)
si_1_2=drop_si_1.iloc[2]
si_1_1_2=drop_si_1.iloc[2].str.replace(',','').astype(int)
si_1_3=drop_si_1.iloc[3]
si_1_1_3=drop_si_1.iloc[3].str.replace(',','').astype(int)
si_1_4=drop_si_1.iloc[4]
si_1_1_4=drop_si_1.iloc[4].str.replace(',','').astype(int)
si_1_5=drop_si_1.iloc[5]
si_1_1_5=drop_si_1.iloc[5].str.replace(',','').astype(int)
si_1_6=drop_si_1.iloc[6]
si_1_1_6=drop_si_1.iloc[6].str.replace(',','').astype(int)

si_1_1_1_1=pd.DataFrame([si_1_1_0,si_1_1_1,si_1_1_2,si_1_1_3,si_1_1_4,si_1_1_5,si_1_1_6])
si_1_1_1_2=pd.DataFrame([si_1_1_2,si_1_1_3])

# %%
si_1_1_1_2
# Out:
#                7     8     9     25   26   27    28   29   30
# Unnamed: 4  10679  2948  7731   843  353  490   964  349  615
# Unnamed: 6   8037  2166  5871  1564  567  997  1302  493  809

# %%
plt.plot(si_1_1_1_2)

plt.show()

# %%
si_2=pd.concat([an_3,bogae,mi,sam],axis=1)
si_2
# Out:
#                          49        50        51       10        11       12  \
# 중앙선거관리위원회 선거통계시스템    안성3동      안성3동      안성3동      보개면       보개면      보개면
# Unnamed: 1              계    관내사전투표     선거일투표        계    관내사전투표    선거일투표
# Unnamed: 2         17,326     2,757    14,569    4,835     1,375    3,460
# Unnamed: 3          8,391     2,750     5,641    2,827     1,374    1,453
# Unnamed: 4          4,319     1,495     2,824    1,243       693      550
# Unnamed: 5              NaN       NaN       NaN      NaN       NaN      NaN
# Unnamed: 6          3,976     1,208     2,768    1,527       665      862
# Unnamed: 7          8,295     2,703     5,592    2,770     1,358    1,412
# Unnamed: 8             96        47        49       57        16       41
# Unnamed: 9          8,935         7     8,928    2,008         1    2,007
#
#                         19        20       21       37        38       39
# 중앙선거관리위원회 선거통계시스템    미양면       미양면      미양면      삼죽면       삼죽면      삼죽면
# ...

# %%
drop_si_2=si_2.drop(["중앙선거관리위원회 선거통계시스템"]).drop(["Unnamed: 1"]).drop(["Unnamed: 5"])
drop_si_2
# Out:
#                   49       50        51       10       11       12       19  \
# Unnamed: 2  17,326    2,757    14,569    4,835    1,375    3,460    5,016
# Unnamed: 3   8,391    2,750     5,641    2,827    1,374    1,453    2,376
# Unnamed: 4   4,319    1,495     2,824    1,243      693      550      888
# Unnamed: 6   3,976    1,208     2,768    1,527      665      862    1,438
# Unnamed: 7   8,295    2,703     5,592    2,770    1,358    1,412    2,326
# Unnamed: 8      96       47        49       57       16       41       50
# Unnamed: 9   8,935        7     8,928    2,008        1    2,007    2,640
#
#                20       21       37     38       39
# Unnamed: 2  854    4,162    3,394    795    2,599
# Unnamed: 3  854    1,522    1,670    794      876
# Unnamed: 4  322      566      685    335      350
# Unnamed: 6  497      941      935    422      513
# Unnamed: 7  819    1,507    1,620    757      863
# Unnamed: 8   35       15       50     37       13
# ...

# %%
si_2_2=drop_si_2.iloc[2]
si_2_1_2=drop_si_2.iloc[2].str.replace(',','').astype(int)
si_2_3=drop_si_2.iloc[3]
si_2_1_3=drop_si_2.iloc[3].str.replace(',','').astype(int)

# %%
si_2_1_1_2=pd.DataFrame([si_2_1_2,si_2_1_3])
si_2_1_1_2
# Out:
#               49    50    51    10   11   12    19   20   21   37   38   39
# Unnamed: 4  4319  1495  2824  1243  693  550   888  322  566  685  335  350
# Unnamed: 6  3976  1208  2768  1527  665  862  1438  497  941  935  422  513

# %%
plt.plot(si_2_1_1_2)

plt.show()

# %%
si_3=pd.concat([an_1,an_2,iill,juck,shoe,go],axis=1)
si_3
# Out:
#                          43        44       45        46        47        48  \
# 중앙선거관리위원회 선거통계시스템    안성1동      안성1동     안성1동      안성2동      안성2동      안성2동
# Unnamed: 1              계    관내사전투표    선거일투표         계    관내사전투표     선거일투표
# Unnamed: 2         10,618     2,563    8,055    20,006     3,391    16,615
# Unnamed: 3          5,671     2,560    3,111     8,957     3,383     5,574
# Unnamed: 4          2,710     1,244    1,466     4,869     1,898     2,971
# Unnamed: 5              NaN       NaN      NaN       NaN       NaN       NaN
# Unnamed: 6          2,861     1,270    1,591     3,979     1,441     2,538
# Unnamed: 7          5,571     2,514    3,057     8,848     3,339     5,509
# Unnamed: 8            100        46       54       109        44        65
# Unnamed: 9          4,947         3    4,944    11,049         8    11,041
#
#                         31        32       33       34        35       36  \
# ...

# %%
drop_si_3=si_3.drop(["중앙선거관리위원회 선거통계시스템"]).drop(["Unnamed: 1"]).drop(["Unnamed: 5"])
drop_si_3
# Out:
#                   43       44       45        46       47        48       31  \
# Unnamed: 2  10,618    2,563    8,055    20,006    3,391    16,615    6,534
# Unnamed: 3   5,671    2,560    3,111     8,957    3,383     5,574    3,441
# Unnamed: 4   2,710    1,244    1,466     4,869    1,898     2,971    1,184
# Unnamed: 6   2,861    1,270    1,591     3,979    1,441     2,538    2,151
# Unnamed: 7   5,571    2,514    3,057     8,848    3,339     5,509    3,335
# Unnamed: 8     100       46       54       109       44        65      106
# Unnamed: 9   4,947        3    4,944    11,049        8    11,041    3,093
#
#                  32       33       34       35       36       16     17  \
# Unnamed: 2  1,562    4,972    6,242    1,717    4,525    2,967    813
# Unnamed: 3  1,560    1,881    3,331    1,716    1,615    1,705    812
# Unnamed: 4    564      620    1,346      716      630      697    359
# Unnamed: 6    917    1,234    1,907      947      960      970    433
# ...

# %%
si_3_2=drop_si_3.iloc[2]
si_3_1_2=drop_si_3.iloc[2].str.replace(',','').astype(int)
si_3_3=drop_si_3.iloc[3]
si_3_1_3=drop_si_3.iloc[3].str.replace(',','').astype(int)

# %%
si_3_1_1_2=pd.DataFrame([si_3_1_2,si_3_1_3])
si_3_1_1_2
# Out:
#               43    44    45    46    47    48    31   32    33    34   35  \
# Unnamed: 4  2710  1244  1466  4869  1898  2971  1184  564   620  1346  716
# Unnamed: 6  2861  1270  1591  3979  1441  2538  2151  917  1234  1907  947
#
#              36   16   17   18   40   41   42
# Unnamed: 4  630  697  359  338  501  249  252
# Unnamed: 6  960  970  433  537  648  299  349

# %%
plt.plot(si_3_1_1_2)

plt.show()

# %%
el_data =pd.read_excel('../Downloads/[제20대_대통령선거]_개표단위별_개표결과.xlsx')
el_data
# Out:
#            중앙선거관리위원회 선거통계시스템 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0    [제20대 대통령선거] 개표단위별 개표결과        NaN        NaN        NaN        NaN
# 1    [국회의원선거][경기도][안성시][안성시]        NaN        NaN        NaN        NaN
# 2                       읍면동명       투표구명       선거인수        투표수   후보자별 득표수
# 3                        NaN        NaN        NaN        NaN  국민의힘\n김학용
# 4                       합계               162,399    116,898     61,445
# 5                     거소투표                   275        240        155
# 6                   관외사전투표                11,813     11,773      6,212
# 7                      공도읍         소계     43,341     28,521     14,824
# 8                              관내사전투표      8,931      8,931      4,313
# 9                              공도읍제1투      4,162      2,477      1,382
# 10                             공도읍제2투      1,675        898        509
# 11                             공도읍제3투      3,183      1,708        914
# ...

# %%
# In[173]:


kongdo_1=pd.concat([el_data.iloc[7],el_data.iloc[8],el_data.iloc[9]],axis=1)



bogae_1=pd.concat([el_data.iloc[10],el_data.iloc[11],el_data.iloc[12]],axis=1)


khumkwang_1=pd.concat([el_data.iloc[13],el_data.iloc[14],el_data.iloc[15]],axis=1)



shoe_1=pd.concat([el_data.iloc[16],el_data.iloc[17],el_data.iloc[18]],axis=1)



mi_1=pd.concat([el_data.iloc[19],el_data.iloc[20],el_data.iloc[21]],axis=1)



dae_1=pd.concat([el_data.iloc[22],el_data.iloc[23],el_data.iloc[24]],axis=1)



yyang_1=pd.concat([el_data.iloc[25],el_data.iloc[26],el_data.iloc[27]],axis=1)



won_1=pd.concat([el_data.iloc[28],el_data.iloc[29],el_data.iloc[30]],axis=1)



# In[181]:


iill_1=pd.concat([el_data.iloc[31],el_data.iloc[32],el_data.iloc[33]],axis=1)



# In[182]:


juck_1=pd.concat([el_data.iloc[34],el_data.iloc[35],el_data.iloc[36]],axis=1)


sam_1=pd.concat([el_data.iloc[37],el_data.iloc[38],el_data.iloc[39]],axis=1)


go_1=pd.concat([el_data.iloc[40],el_data.iloc[41],el_data.iloc[42]],axis=1)



an_1_1=pd.concat([el_data.iloc[43],el_data.iloc[44],el_data.iloc[45]],axis=1)


an_2_1=pd.concat([el_data.iloc[46],el_data.iloc[47],el_data.iloc[48]],axis=1)


an_3_1=pd.concat([el_data.iloc[49],el_data.iloc[50],el_data.iloc[51]],axis=1)

# %%
si_1_1=pd.concat([kongdo_1,yyang_1,won_1],axis=1)



drop_si_1_1=si_1_1.drop(["중앙선거관리위원회 선거통계시스템"]).drop(["Unnamed: 1"]).drop(["Unnamed: 5"])



# In[317]:


si_1_1_10=drop_si_1_1.iloc[0]
si_1_1_1_0=drop_si_1_1.iloc[0].str.replace(',','').astype(int)
si_1_1_1=drop_si_1_1.iloc[1]
si_1_1_1_1=drop_si_1_1.iloc[1].str.replace(',','').astype(int)
si_1_1_2=drop_si_1_1.iloc[2]
si_1_1_1_2=drop_si_1_1.iloc[2].str.replace(',','').astype(int)
si_1_1_3=drop_si_1_1.iloc[3]
si_1_1_1_3=drop_si_1_1.iloc[3].str.replace(',','').astype(int)
si_1_1_4=drop_si_1_1.iloc[4]
si_1_1_1_4=drop_si_1_1.iloc[4].str.replace(',','').astype(int)
si_1_1_5=drop_si_1_1.iloc[5]
si_1_1_1_5=drop_si_1_1.iloc[5].str.replace(',','').astype(int)
si_1_1_6=drop_si_1_1.iloc[6]
si_1_1_1_6=drop_si_1_1.iloc[6].str.replace(',','').astype(int)

si_1_1_1_1_2=pd.DataFrame([si_1_1_1_2,si_1_1_1_3])


# In[307]:


si_1_1_1_1_2
# Out:
#                7     8     9    25    26   27   28   29   30
# Unnamed: 4  14824  4313  1382  242  2333  877  363  180  190
# Unnamed: 6   6105  2213   462   43   912  391   71   47   60

# %%
plt.plot(si_1_1_1_1_2)

plt.show()

# %%
si_1_2=pd.concat([an_3_1,bogae_1,mi_1,sam_1],axis=1)



drop_si_1_2=si_1_2.drop(["중앙선거관리위원회 선거통계시스템"]).drop(["Unnamed: 1"]).drop(["Unnamed: 5"])
drop_si_1_2


# In[319]:


si_2_1_2=drop_si_1_2.iloc[2]
si_2_1_1_2=drop_si_1_2.iloc[2].str.replace(',','').astype(int)
si_2_1_3=drop_si_1_2.iloc[3]
si_2_1_1_3=drop_si_1_2.iloc[3].str.replace(',','').astype(int)


# In[321]:


si_2_1_1_1_2=pd.DataFrame([si_2_1_1_2,si_2_1_1_3])
si_2_1_1_1_2
# Out:
#               49   50   51   10   11   12    19    20    21   37    38   39
# Unnamed: 4  2026  927  376  509  914  854  1249  2183  1150  182  1854  850
# Unnamed: 6   539  272   95  170  310  277   493   676   424   22   512  295

# %%
plt.plot(si_2_1_1_1_2)

plt.show()

# %%
si_1_3=pd.concat([an_1_1,an_2_1,iill_1,juck_1,shoe_1,go_1],axis=1)


drop_si_1_3=si_1_3.drop(["중앙선거관리위원회 선거통계시스템"]).drop(["Unnamed: 1"]).drop(["Unnamed: 5"])



si_3_1_2=drop_si_1_3.iloc[2]
si_3_1_1_2=drop_si_1_3.iloc[2].str.replace(',','').astype(int)
si_3_1_3=drop_si_1_3.iloc[3]
si_3_1_1_3=drop_si_1_3.iloc[3].str.replace(',','').astype(int)


# In[325]:


si_3_1_1_3=pd.DataFrame([si_3_1_1_2,si_3_1_1_3])
si_3_1_1_3
# Out:
#               43    44   45   46   47    48   31   32    33   34   35   36  \
# Unnamed: 4  4163  1662  384  348  733  1036  178  545  1443  745  321  195
# Unnamed: 6  1732   854   87   99  259   433   25  318   312  201   65   24
#
#              16   17   18   40   41   42
# Unnamed: 4  830  551  932  311  414  279
# Unnamed: 6  436  227  356   61  108   48

# %%
plt.plot(si_3_1_1_3)
plt.show()

# %%
ele_data =pd.read_excel('../Downloads/개표현황&_#40;읍면동별&_#41;.xlsx')
ele_data
# Out:
#                    중앙선거관리위원회 선거통계시스템       Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                         개표현황(읍면동별)              NaN        NaN        NaN
# 1   [제21대][국회의원선거][국회의원선거][경기도][안성시]              NaN        NaN        NaN
# 2                               선거구명             읍면동명         구분       선거인수
# 3                                NaN              NaN        NaN        NaN
# 4                              안성시               합계               155,021
# 5                                           거소·선상투표                   238
# 6                                            관외사전투표                 6,985
# 7                                           국외부재자투표                   378
# 8                                       국외부재자투표(공관)                     0
# 9                                               공도읍          계     41,975
# 10                                              공도읍     관내사전투표      6,547
# ...

# %%
kongdo_2=pd.concat([ele_data.iloc[7],ele_data.iloc[8],ele_data.iloc[9]],axis=1)



bogae_2=pd.concat([ele_data.iloc[10],ele_data.iloc[11],ele_data.iloc[12]],axis=1)


khumkwang_2=pd.concat([ele_data.iloc[13],ele_data.iloc[14],ele_data.iloc[15]],axis=1)



shoe_2=pd.concat([ele_data.iloc[16],ele_data.iloc[17],ele_data.iloc[18]],axis=1)



mi_2=pd.concat([ele_data.iloc[19],ele_data.iloc[20],ele_data.iloc[21]],axis=1)



dae_2=pd.concat([ele_data.iloc[22],ele_data.iloc[23],ele_data.iloc[24]],axis=1)



yyang_2=pd.concat([ele_data.iloc[25],ele_data.iloc[26],ele_data.iloc[27]],axis=1)



won_2=pd.concat([ele_data.iloc[28],ele_data.iloc[29],ele_data.iloc[30]],axis=1)



# In[181]:


iill_2=pd.concat([ele_data.iloc[31],ele_data.iloc[32],ele_data.iloc[33]],axis=1)



# In[182]:


juck_2=pd.concat([ele_data.iloc[34],ele_data.iloc[35],ele_data.iloc[36]],axis=1)


sam_2=pd.concat([ele_data.iloc[37],ele_data.iloc[38],ele_data.iloc[39]],axis=1)


go_2=pd.concat([ele_data.iloc[40],ele_data.iloc[41],ele_data.iloc[42]],axis=1)



an_1_2=pd.concat([ele_data.iloc[43],ele_data.iloc[44],ele_data.iloc[45]],axis=1)


an_2_2=pd.concat([ele_data.iloc[46],ele_data.iloc[47],ele_data.iloc[48]],axis=1)


an_3_2=pd.concat([ele_data.iloc[49],ele_data.iloc[50],ele_data.iloc[51]],axis=1)

# %%
si_2_1=pd.concat([kongdo_2,yyang_2,won_2],axis=1)



# In[203]:


drop_si_2=si_2_1.drop(["중앙선거관리위원회 선거통계시스템"]).drop(["Unnamed: 1"]).drop(["Unnamed: 2"]).drop(["Unnamed: 6"])




# In[317]:

drop_si_2
# Out:
#                 7     8         9        25       26       27       28  \
# Unnamed: 3   378     0    41,975    2,772    9,784    4,776    1,333
# Unnamed: 4    71     7    24,001    2,769    4,361    3,145    1,333
# Unnamed: 5    40     3    13,639    1,591    2,181    1,180      604
# Unnamed: 7    29     4     9,743    1,125    2,025    1,820      685
# Unnamed: 8     2     0       279       23       81       56       19
# Unnamed: 9    71     7    23,661    2,739    4,287    3,056    1,308
# Unnamed: 10    0     0       340       30       74       89       25
# Unnamed: 11  307    -7    17,974        3    5,423    1,631        0
#
#                   29       30
# Unnamed: 3   3,443    5,114
# Unnamed: 4   1,812    2,915
# Unnamed: 5     576    1,252
# Unnamed: 7   1,135    1,547
# Unnamed: 8      37       42
# Unnamed: 9   1,748    2,841
# Unnamed: 10     64       74
# Unnamed: 11  1,631    2,199

# %%
si_2_1_0=drop_si_2.iloc[0]
si_2_1_2_0=drop_si_2.iloc[0].str.replace(',','').astype(int)
si_2_1=drop_si_2.iloc[1]
si_2_1_1=drop_si_2.iloc[1].str.replace(',','').astype(int)
si_2_2=drop_si_2.iloc[2]
si_2_1_2=drop_si_2.iloc[2].str.replace(',','').astype(int)
si_2_3=drop_si_2.iloc[3]
si_2_1_3=drop_si_2.iloc[3].str.replace(',','').astype(int)
si_2_4=drop_si_2.iloc[4]
si_2_1_4=drop_si_2.iloc[4].str.replace(',','').astype(int)
si_2_5=drop_si_2.iloc[5]
si_2_1_5=drop_si_2.iloc[5].str.replace(',','').astype(int)
si_2_6=drop_si_2.iloc[6]
si_2_1_6=drop_si_1.iloc[6].str.replace(',','').astype(int)

si_2_1_1_2=pd.DataFrame([si_2_1_2,si_2_1_3])


# In[307]:


si_2_1_1_2
# Out:
#             7   8      9     25    26    27   28    29    30
# Unnamed: 5  40   3  13639  1591  2181  1180  604   576  1252
# Unnamed: 7  29   4   9743  1125  2025  1820  685  1135  1547

# %%
plt.plot(si_2_1_1_2)
plt.show()

# %%
si_2_2=pd.concat([an_3_2,bogae_2,mi_2,sam_2],axis=1)

drop_si_2_2=si_2_2.drop(["중앙선거관리위원회 선거통계시스템"]).drop(["Unnamed: 1"]).drop(["Unnamed: 2"]).drop(["Unnamed: 6"])



# In[319]:


si_2_2_2=drop_si_2_2.iloc[2]
si_2_2_2=drop_si_2_2.iloc[2].str.replace(',','').astype(int)
si_2_2_3=drop_si_2_2.iloc[3]
si_2_2_3=drop_si_2_2.iloc[3].str.replace(',','').astype(int)


# In[321]:


si_2_2_1_2=pd.DataFrame([si_2_2_2,si_2_2_3])
si_2_2_1_2
# Out:
#               49    50    51    10    11    12   19   20    21   37    38   39
# Unnamed: 5  2665  3199  5633  4151  9488  1563  514  368  1422  924   769  916
# Unnamed: 7  1793  2902  5033  2285  7458  1844  546  693  1644  895  1148  984

# %%
plt.plot(si_2_2_1_2)
plt.show()

# %%
si_2_3=pd.concat([an_1_2,an_2_2,iill_2,juck_2,shoe_2,go_2],axis=1)


drop_si_2_3=si_2_2.drop(["중앙선거관리위원회 선거통계시스템"]).drop(["Unnamed: 1"]).drop(["Unnamed: 2"]).drop(["Unnamed: 6"])



si_3_2_2=drop_si_2_3.iloc[2]
si_3_1_2_2=drop_si_2_3.iloc[2].str.replace(',','').astype(int)
si_3_2_3=drop_si_2_3.iloc[3]
si_3_1_2_3=drop_si_2_3.iloc[3].str.replace(',','').astype(int)


# In[325]:


si_3_1_1_3=pd.DataFrame([si_3_1_2_2,si_3_1_2_3])
si_3_1_1_3
# Out:
#               49    50    51    10    11    12   19   20    21   37    38   39
# Unnamed: 5  2665  3199  5633  4151  9488  1563  514  368  1422  924   769  916
# Unnamed: 7  1793  2902  5033  2285  7458  1844  546  693  1644  895  1148  984

# %%
plt.plot(si_3_1_1_3)
plt.show()

# %% [markdown]
# # 만약 초반을 리드 할 수 있으면 어떻게 할까

# %%
eight_data =pd.read_excel('../Downloads/[제20대_대통령선거]_개표진행상황 (1).xlsx')
eight_data.iloc[4]
# Out:
# 중앙선거관리위원회 선거통계시스템          안성시
# Unnamed: 1
# Unnamed: 2
# Unnamed: 3
# Unnamed: 4           국민의힘\n김학용
# Unnamed: 5            정의당\n이주현
# Unnamed: 6                   NaN
# Unnamed: 7            무소속\n이기영
# Unnamed: 8                   계
# Unnamed: 9
# Unnamed: 10
# Unnamed: 11
# Name: 4, dtype: object

# %%
early_data =pd.read_excel('../Downloads/[제20대_대통령선거]_개표단위별_개표결과.xlsx')
early_data
# Out:
#            중앙선거관리위원회 선거통계시스템 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0    [제20대 대통령선거] 개표단위별 개표결과        NaN        NaN        NaN        NaN
# 1    [국회의원선거][경기도][안성시][안성시]        NaN        NaN        NaN        NaN
# 2                       읍면동명       투표구명       선거인수        투표수   후보자별 득표수
# 3                        NaN        NaN        NaN        NaN  국민의힘\n김학용
# 4                       합계               162,399    116,898     61,445
# 5                     거소투표                   275        240        155
# 6                   관외사전투표                11,813     11,773      6,212
# 7                      공도읍         소계     43,341     28,521     14,824
# 8                              관내사전투표      8,931      8,931      4,313
# 9                              공도읍제1투      4,162      2,477      1,382
# 10                             공도읍제2투      1,675        898        509
# 11                             공도읍제3투      3,183      1,708        914
# ...

# %%
number=pd.read_excel('../Downloads/투표현황.xlsx')
number
# Out:
#        중앙선거관리위원회 선거통계시스템       Unnamed: 1    Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                   투표현황              NaN           NaN        NaN        NaN
# 1    [제21대][국회의원선거][경기도]              NaN           NaN        NaN        NaN
# 2                   구시군명               구분          선거인수  시간대별 투표현황        NaN
# 3                    NaN              NaN           NaN         7시         8시
# 4                   합계                계    11,067,819    228,462    574,587
# 5                         사전+거소+\n선상+재외     2,708,550          -          -
# 6                                투표율(%)             -        2.1        5.2
# 7               수원시장안구                계       197,970      4,087     11,151
# 8                         사전+거소+\n선상+재외        49,930          -          -
# 9                                투표율(%)             -        2.1        5.6
# 10              수원시권선구                계       443,167     11,157     22,923
# ...

# %%
number_1=number_0.drop(["중앙선거관리위원회 선거통계시스템"]).drop(["Unnamed: 1"]).drop(["Unnamed: 3"]).drop(["Unnamed: 4"]).drop(["Unnamed: 5"]).drop(["Unnamed: 6"]).drop(["Unnamed: 7"]).drop(["Unnamed: 8"]).drop(["Unnamed: 9"]).drop(["Unnamed: 10"]).drop(["Unnamed: 11"]).drop(["Unnamed: 12"]).drop(["Unnamed: 13"]).drop(["Unnamed: 14"]).drop(["Unnamed: 15"])

# %%
number_2=number_1.str.replace(',','').astype(int)

# %%
arm_data =pd.read_excel('../Downloads/[제8회_전국동시지방선거]_사전투표진행상황.xlsx')
arm_data
# Out:
#           중앙선거관리위원회 선거통계시스템    Unnamed: 1  Unnamed: 2   Unnamed: 3 Unnamed: 4
# 0   [제8회 전국동시지방선거] 사전투표진행상황           NaN         NaN          NaN        NaN
# 1         [경기도][2일차 누계][7시]           NaN         NaN          NaN        NaN
# 2                      구시군명          선거인수         NaN       사전투표자수   사전투표율(%)
# 3                      합계    11,497,206           NaN  1,089,660       9.48
# 4                  수원시장안구       199,204           NaN     20,235      10.16
# 5                  수원시권선구       352,407           NaN     30,464       8.64
# 6                  수원시팔달구       164,086           NaN     15,245       9.29
# 7                  수원시영통구       296,856           NaN     26,674       8.99
# 8                  성남시수정구       208,907           NaN     23,947      11.46
# 9                  성남시중원구       185,468           NaN     20,442      11.02
# 10                 성남시분당구       404,133           NaN     42,103      10.42
# ...

# %%
kt=arm_data.iloc[39]
kt
# Out:
# 중앙선거관리위원회 선거통계시스템        안성시
# Unnamed: 1           163,518
# Unnamed: 2                 NaN
# Unnamed: 3            18,730
# Unnamed: 4             11.45
# Name: 39, dtype: object

# %%
kt_0=kt.drop(["Unnamed: 2"])

# %%
kt_1=kt_0.drop(["중앙선거관리위원회 선거통계시스템"])

# %%
kt_2=kt_1.str.replace(',','')
kt_3=kt_2.str.replace(' ,','')
kt_4=kt_3.str.replace('.','')
# Out:
# /var/folders/kz/g7t1dwnn7w1_cq7td6y2rfqc0000gn/T/ipykernel_3877/1661063127.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   kt_4=kt_3.str.replace('.','')

# %%
kt_5=kt_4.astype(int)
kt_5
# Out:
# Unnamed: 1    163518
# Unnamed: 3     18730
# Unnamed: 4      1145
# Name: 39, dtype: int64

# %%
kt_6=kt_5.drop(["Unnamed: 4"])
kt_6

x=['all','Voting']
plt.bar(x,kt_6)
plt.xticks(x)
plt.show()

# %%
kd=raw_data.iloc[4]

kd_0=kd.str.replace(',','')
kd_0
# Out:
# 중앙선거관리위원회 선거통계시스템        합계
# Unnamed: 1
# Unnamed: 2           163518
# Unnamed: 3            81762
# Unnamed: 4            40497
# Unnamed: 5                NaN
# Unnamed: 6            39930
# Unnamed: 7            80427
# Unnamed: 8             1335
# Unnamed: 9            81756
# Name: 4, dtype: object

# %%
kd_1=kd_0.drop((["중앙선거관리위원회 선거통계시스템"])).drop((["Unnamed: 1"])).drop((["Unnamed: 3"])).drop((["Unnamed: 5"])).drop((["Unnamed: 7"])).drop((["Unnamed: 8"])).drop((["Unnamed: 9"]))

# %%
kd_2=kd_1.astype(int)
kd_2
# Out:
# Unnamed: 2    163518
# Unnamed: 4     40497
# Unnamed: 6     39930
# Name: 4, dtype: int64

# %%
x=['all','kim','lee']
plt.bar(x,kd_2)
plt.xticks(x)
plt.show()

# %%
x=['all','Voting']
plt.bar(x,number_2)
plt.xticks(x)
plt.show()

# %%
ele_data
# Out:
#                    중앙선거관리위원회 선거통계시스템       Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                         개표현황(읍면동별)              NaN        NaN        NaN
# 1   [제21대][국회의원선거][국회의원선거][경기도][안성시]              NaN        NaN        NaN
# 2                               선거구명             읍면동명         구분       선거인수
# 3                                NaN              NaN        NaN        NaN
# 4                              안성시               합계               155,021
# 5                                           거소·선상투표                   238
# 6                                            관외사전투표                 6,985
# 7                                           국외부재자투표                   378
# 8                                       국외부재자투표(공관)                     0
# 9                                               공도읍          계     41,975
# 10                                              공도읍     관내사전투표      6,547
# ...

# %%
rd=eight_data.iloc[5]
rd
# Out:
# 중앙선거관리위원회 선거통계시스템
# Unnamed: 1               안성시
# Unnamed: 2           162,399
# Unnamed: 3           116,898
# Unnamed: 4            61,445
# Unnamed: 5            22,854
# Unnamed: 6                 NaN
# Unnamed: 7            29,106
# Unnamed: 8           113,405
# Unnamed: 9             3,493
# Unnamed: 10           45,501
# Unnamed: 11            100.0
# Name: 5, dtype: object

# %%
md=ele_data.iloc[4]
md
# Out:
# 중앙선거관리위원회 선거통계시스템        안성시
# Unnamed: 1                합계
# Unnamed: 2
# Unnamed: 3           155,021
# Unnamed: 4            98,475
# Unnamed: 5            49,721
# Unnamed: 6                 NaN
# Unnamed: 7            45,554
# Unnamed: 8             1,372
# Unnamed: 9            96,647
# Unnamed: 10            1,828
# Unnamed: 11           56,546
# Name: 4, dtype: object

# %%
md_0=md.drop(["중앙선거관리위원회 선거통계시스템"]).drop(["Unnamed: 1"]).drop(["Unnamed: 2"]).drop(["Unnamed: 6"]).drop(["Unnamed: 9"]).drop(["Unnamed: 10"]).drop(["Unnamed: 11"])
md_1=md_0.str.replace(',','').astype(int)
md_1
# Out:
# Unnamed: 3    155021
# Unnamed: 4     98475
# Unnamed: 5     49721
# Unnamed: 7     45554
# Unnamed: 8      1372
# Name: 4, dtype: int64

# %%
rd=early_data.iloc[6]
rd
# Out:
# 중앙선거관리위원회 선거통계시스템    관외사전투표
# Unnamed: 1
# Unnamed: 2           11,813
# Unnamed: 3           11,773
# Unnamed: 4            6,212
# Unnamed: 5                NaN
# Unnamed: 6            2,698
# Unnamed: 7            2,312
# Unnamed: 8           11,222
# Unnamed: 9              551
# Unnamed: 10              40
# Name: 6, dtype: object

# %%
rd_0=rd.drop(["중앙선거관리위원회 선거통계시스템"]).drop(["Unnamed: 1"]).drop(["Unnamed: 5"]).drop(["Unnamed: 9"]).drop(["Unnamed: 10"])

# %%
rd_1=rd_0.str.replace(',','')
rd_2=rd_1.astype(int)
rd_2
# Out:
# Unnamed: 2    11813
# Unnamed: 3    11773
# Unnamed: 4     6212
# Unnamed: 6     2698
# Unnamed: 7     2312
# Unnamed: 8    11222
# Name: 6, dtype: int64

# %%
x=['all','Voting number','kim','lee_yellow','lee','Voting sum']
plt.bar(x,rd_2)
plt.xticks(x)
plt.show()

# %%
early_data.iloc[6]
# Out:
# 중앙선거관리위원회 선거통계시스템    관외사전투표
# Unnamed: 1
# Unnamed: 2           11,813
# Unnamed: 3           11,773
# Unnamed: 4            6,212
# Unnamed: 5                NaN
# Unnamed: 6            2,698
# Unnamed: 7            2,312
# Unnamed: 8           11,222
# Unnamed: 9              551
# Unnamed: 10              40
# Name: 6, dtype: object

# %%
kr=early_data.iloc[6].drop(["중앙선거관리위원회 선거통계시스템"]).drop(["Unnamed: 1"]).drop(["Unnamed: 5"]).drop(["Unnamed: 9"])
kr
# Out:
# Unnamed: 2     11,813
# Unnamed: 3     11,773
# Unnamed: 4      6,212
# Unnamed: 6      2,698
# Unnamed: 7      2,312
# Unnamed: 8     11,222
# Unnamed: 10        40
# Name: 6, dtype: object

# %%
kr_0=kr.str.replace(',','').astype(int)

# %%
x=['all','Voting number','kim','lee_yellow','lee','Voting sum','give up']
plt.bar(x,kr_0)
plt.xticks(x)
plt.show()

# %%
ele_data
# Out:
#                    중앙선거관리위원회 선거통계시스템       Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                         개표현황(읍면동별)              NaN        NaN        NaN
# 1   [제21대][국회의원선거][국회의원선거][경기도][안성시]              NaN        NaN        NaN
# 2                               선거구명             읍면동명         구분       선거인수
# 3                                NaN              NaN        NaN        NaN
# 4                              안성시               합계               155,021
# 5                                           거소·선상투표                   238
# 6                                            관외사전투표                 6,985
# 7                                           국외부재자투표                   378
# 8                                       국외부재자투표(공관)                     0
# 9                                               공도읍          계     41,975
# 10                                              공도읍     관내사전투표      6,547
# ...

# %%
el_data
# Out:
#            중앙선거관리위원회 선거통계시스템 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0    [제20대 대통령선거] 개표단위별 개표결과        NaN        NaN        NaN        NaN
# 1    [국회의원선거][경기도][안성시][안성시]        NaN        NaN        NaN        NaN
# 2                       읍면동명       투표구명       선거인수        투표수   후보자별 득표수
# 3                        NaN        NaN        NaN        NaN  국민의힘\n김학용
# 4                       합계               162,399    116,898     61,445
# 5                     거소투표                   275        240        155
# 6                   관외사전투표                11,813     11,773      6,212
# 7                      공도읍         소계     43,341     28,521     14,824
# 8                              관내사전투표      8,931      8,931      4,313
# 9                              공도읍제1투      4,162      2,477      1,382
# 10                             공도읍제2투      1,675        898        509
# 11                             공도읍제3투      3,183      1,708        914
# ...

# %%
x=['all','Voting']
plt.bar(x,kt_6)
plt.xticks(x)
plt.show()

# %%
x=['all','kim','lee']
plt.bar(x,kd_2)
plt.xticks(x)
plt.show()

# %%
x=['all','Voting number','kim','lee_yellow','lee','Voting sum']
plt.bar(x,rd_2)
plt.xticks(x)
plt.show()

# %%
x=['all','Voting number','kim','lee_yellow','lee','Voting sum','give up']
plt.bar(x,kr_0)
plt.xticks(x)
plt.show()

# %%
x=['all','Voting']
plt.bar(x,number_2)
plt.xticks(x)
plt.show()

# %%
x=['all','vovild','lee','kim','song']
plt.bar(x,md_1)
plt.xticks(x)
plt.show()

# %%
kd=pd.read_excel('../Downloads/안성시 주민등록.xlsx')
kd_0=pd.concat([kd['Unnamed: 1'],kd['Unnamed: 2'],kd['Unnamed: 8'],kd['Unnamed: 14'],kd['Unnamed: 20'],kd['Unnamed: 26'],kd['Unnamed: 32'],kd['Unnamed: 38'],kd['Unnamed: 44'],kd['Unnamed: 50'],kd['Unnamed: 56'],kd['Unnamed: 62'],kd['Unnamed: 68'],kd['Unnamed: 74'],kd['Unnamed: 80'],kd['Unnamed: 86'],kd['Unnamed: 92'],kd['Unnamed: 98'],kd['Unnamed: 104'],kd['Unnamed: 110'],kd['Unnamed: 116'],kd['Unnamed: 122'],kd['Unnamed: 128'],kd['Unnamed: 134'],kd['Unnamed: 140'],kd['Unnamed: 146'],kd['Unnamed: 152'],kd['Unnamed: 158'],kd['Unnamed: 164'],kd['Unnamed: 170'],kd['Unnamed: 176'],kd['Unnamed: 182'],kd['Unnamed: 188'],kd['Unnamed: 194'],kd['Unnamed: 200'],kd['Unnamed: 206'],kd['Unnamed: 212'],kd['Unnamed: 218'],kd['Unnamed: 224'],kd['Unnamed: 230'],kd['Unnamed: 236'],kd['Unnamed: 242'],kd['Unnamed: 248'],kd['Unnamed: 254'],kd['Unnamed: 260'],kd['Unnamed: 266'],kd['Unnamed: 272'],kd['Unnamed: 278'],kd['Unnamed: 284'],kd['Unnamed: 290'],kd['Unnamed: 296']],axis=1)

# %%
kd_1=kd_0.drop(index=0).drop(index=1)
kd_1['Unnamed: 1']
# Out:
# 2         경기도 안성시
# 3      경기도 안성시 공도읍
# 4      경기도 안성시 보개면
# 5      경기도 안성시 금광면
# 6      경기도 안성시 서운면
# 7      경기도 안성시 미양면
# 8      경기도 안성시 대덕면
# 9      경기도 안성시 양성면
# 10     경기도 안성시 원곡면
# 11     경기도 안성시 일죽면
# 12     경기도 안성시 죽산면
# 13     경기도 안성시 삼죽면
# 14     경기도 안성시 고삼면
# 15    경기도 안성시 안성1동
# 16    경기도 안성시 안성2동
# 17    경기도 안성시 안성3동
# Name: Unnamed: 1, dtype: object

# %%
gd_0=pd.concat([kd['Unnamed: 2'],kd['Unnamed: 8'],kd['Unnamed: 14'],kd['Unnamed: 20'],kd['Unnamed: 26'],kd['Unnamed: 32'],kd['Unnamed: 38'],kd['Unnamed: 44'],kd['Unnamed: 50'],kd['Unnamed: 56'],kd['Unnamed: 62'],kd['Unnamed: 68'],kd['Unnamed: 74'],kd['Unnamed: 80'],kd['Unnamed: 86'],kd['Unnamed: 92'],kd['Unnamed: 98'],kd['Unnamed: 104'],kd['Unnamed: 110'],kd['Unnamed: 116'],kd['Unnamed: 122'],kd['Unnamed: 128'],kd['Unnamed: 134'],kd['Unnamed: 140'],kd['Unnamed: 146'],kd['Unnamed: 152'],kd['Unnamed: 158'],kd['Unnamed: 164'],kd['Unnamed: 170'],kd['Unnamed: 176'],kd['Unnamed: 182'],kd['Unnamed: 188'],kd['Unnamed: 194'],kd['Unnamed: 200'],kd['Unnamed: 206'],kd['Unnamed: 212'],kd['Unnamed: 218'],kd['Unnamed: 224'],kd['Unnamed: 230'],kd['Unnamed: 236'],kd['Unnamed: 242'],kd['Unnamed: 248'],kd['Unnamed: 254'],kd['Unnamed: 260'],kd['Unnamed: 266'],kd['Unnamed: 272'],kd['Unnamed: 278'],kd['Unnamed: 284'],kd['Unnamed: 290'],kd['Unnamed: 296']],axis=1)

# %%
gd_1=gd_0.drop(index=0).drop(index=1)

# %%
for i in range(16):
    gd_2=gd_1.iloc[i].str.replace(',','').astype(int)
    gd_3=pd.concat([gd_3.append(gd_2)],axis=1)
# Out:
# /var/folders/kz/g7t1dwnn7w1_cq7td6y2rfqc0000gn/T/ipykernel_3877/1699926005.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gd_3=pd.concat([gd_3.append(gd_2)],axis=1)
# /var/folders/kz/g7t1dwnn7w1_cq7td6y2rfqc0000gn/T/ipykernel_3877/1699926005.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gd_3=pd.concat([gd_3.append(gd_2)],axis=1)
# /var/folders/kz/g7t1dwnn7w1_cq7td6y2rfqc0000gn/T/ipykernel_3877/1699926005.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   gd_3=pd.concat([gd_3.append(gd_2)],axis=1)
# ...

# %%
gd_4=gd_3.drop(index='Unnamed: 2').drop(index='Unnamed: 8').drop(index='Unnamed: 14').drop(index='Unnamed: 20').drop(index='Unnamed: 26').drop(index='Unnamed: 32').drop(index='Unnamed: 38').drop(index='Unnamed: 44').drop(index='Unnamed: 50').drop(index='Unnamed: 56').drop(index='Unnamed: 62').drop(index='Unnamed: 68').drop(index='Unnamed: 74').drop(index='Unnamed: 80').drop(index='Unnamed: 86').drop(index='Unnamed: 92').drop(index='Unnamed: 98').drop(index='Unnamed: 104').drop(index='Unnamed: 110').drop(index='Unnamed: 116').drop(index='Unnamed: 122').drop(index='Unnamed: 128').drop(index='Unnamed: 134').drop(index='Unnamed: 140').drop(index='Unnamed: 146').drop(index='Unnamed: 152').drop(index='Unnamed: 158').drop(index='Unnamed: 164').drop(index='Unnamed: 170').drop(index='Unnamed: 176').drop(index='Unnamed: 182').drop(index='Unnamed: 188').drop(index='Unnamed: 194').drop(index='Unnamed: 200').drop(index='Unnamed: 206').drop(index='Unnamed: 212').drop(index='Unnamed: 218').drop(index='Unnamed: 224').drop(index='Unnamed: 230').drop(index='Unnamed: 236').drop(index='Unnamed: 242').drop(index='Unnamed: 248').drop(index='Unnamed: 254').drop(index='Unnamed: 260').drop(index='Unnamed: 266').drop(index='Unnamed: 272').drop(index='Unnamed: 278').drop(index='Unnamed: 284').drop(index='Unnamed: 290').drop(index='Unnamed: 296')

# %%
gd_5=gd_4.drop(columns=17)[:16]

# %%
nd=pd.concat([kd_1['Unnamed: 1'],gd_5],axis=1)
nd
# Out:
#       Unnamed: 1 Unnamed: 2 Unnamed: 8 Unnamed: 14 Unnamed: 20 Unnamed: 26  \
# 2       경기도 안성시      182421     182188      182186      182231      182310
# 3    경기도 안성시 공도읍      56897      56972       57033       56948       56889
# 4    경기도 안성시 보개면       5723       5697        5691        5658        5642
# 5    경기도 안성시 금광면       7912       7894        7906        7852        7789
# 6    경기도 안성시 서운면       3598       3580        3577        3552        3541
# 7    경기도 안성시 미양면       5961       5942        5960        5905        5875
# 8    경기도 안성시 대덕면      15968      15953       15923       15815       15732
# 9    경기도 안성시 양성면       5275       5274        5251        5273        5276
# 10   경기도 안성시 원곡면       5653       5718        5790        5870        5903
# 11   경기도 안성시 일죽면       7955       7754        7698        7670        7668
# 12   경기도 안성시 죽산면       7141       7107        7079        7038        7028
# ...

# %%
gd_6=gd_5.astype(int)
gd_7=gd_6.drop(index=2)

# %%
plt.plot(gd_7)
plt.show()

# %%
plt.plot(gd_7.iloc[0])
plt.show()

# %%
plt.plot(gd_7.iloc[1])
plt.show()

# %%
plt.plot(gd_7.iloc[8])
plt.show()

# %%
plt.plot(gd_7.iloc[14])
plt.show()

# %% [markdown]
# # 결론 공도가 중요하다
